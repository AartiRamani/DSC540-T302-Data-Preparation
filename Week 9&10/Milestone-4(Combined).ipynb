# %% [markdown]
# # Airlines On-Time Performance, Delays, Cancellations and Diversions
#
# ## Milestone 1 -
# ### Introduction:
# >Airline cancellations or delays are one of the major causes of passenger inconvenience. With
# the publicly available dataset, using data science, I am hoping to gain meaningful insights into the best-performing airlines and understand the causes of delays, diversions and cancellations across different airline carriers.
# For the final project, I would like to analyze airline data to identify different factors and their effects on a carrier's performance. As a performance measure, I would like to explore on-time arrivals, and the number of cancellations by
# the carrier and explore different reasons for delays and diversions. Based on the outcome, carriers can take necessary actions to focus on the problem areas.
#
#
# ### Data Source:
# -  Flat File: Excel files from BTS. The Excel data has airline performance factors such as cancelled, diverted, delayed and on-time data. The downloaded raw data has up to 34 columns.
# https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp?20=E (Download Raw Data link for data).
# - API: API provides historical weather information. https://visual-crossing-weather.p.rapidapi.com/history?startDateTime={}&aggregateHours=24&location={}&endDateTime={}&unitGroup=us
# -  Website: The website consists of a list of diverted flights. https://www.diverted.eu/
#
#
# ### Relationships:
# > The Flat file is the main data source with scheduled flight information.
#
# >   Flat File - API:
#
# >   Data from the flat file has cancellations and delays due to weather. I would like to look up the weather information for the flight date at the origin/destination of flights cancelled or delayed due to bad weather. The Bureau data has up to January 2023 data. To look up the weather for a past date, I would need historic weather data. The API gets the historic
# weather data for a location (origin or destination city name). This will enable us to validate if there truly was a bad weather situation for a flight to be delayed or cancelled. With this, we can also identify the cause of bad weather like storms, snow, wind, etc.
#
# >   - Flat file has many to many relation with the API. We will need to pass the flight date and the origin or destination city to the API to get weather information for a particular date and place.
#
# >   Flat File - Website:
#
# >   The flat file has a column for diverted flights but does not have any information on the cause for diversion. I would like to look up the reason for a flight being diverted. The website and flat file can be matched on flight date, origin and destination to lookup diverted flight information.
#
# >  - Flat file has many to many relation with the Website. We will need to pass the flight date and the origin and destination city to the website to get flight diversion details for a particular date and route.
#
#
# ### Project Subject Area:
# >The project aims on identifying various performance measures in airline operations. Using the statistical analysis we can gain insights into the best and least performing airline carriers and the most common reasons for delays and cancellations.
#
#
# ### Challenges:
# >The flight performance data size is huge (flat file). I would have to find ways to reduce data to
# a reasonable size without losing meaningful information.
#
#
# ### Conclusion:
# >For the first project milestone, I have identified data from different sources in different formats. I will be applying various data cleansing and visualization techniques on this dataset to gain meaningful insights in the upcoming project milestones.

# %% [markdown]
# ## Milestone 2 - Cleaning/Formatting Flat File Source

# %% [markdown]
# >Flat File: Excel files from BTS. The Excel data has airline performance factors such as cancelled, diverted, delayed and on-time data. The downloaded raw data has up to 34 columns. https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp?20=E (Download Raw Data link for data).
# The Flat file is the main data source with scheduled flight information.

# %%
# Import necessary libraries

import pandas as pd
from datetime import datetime
import numpy as np

#Milestone 3 libraries
from urllib.request import Request, urlopen 
from bs4 import BeautifulSoup

#Milestone 4 libraries
#import requests
import urllib.request, urllib.parse, urllib.error
import json  
import requests
import re

# %%
#Read flight data from "https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp?20=E" into a dataframe

flight_data_df = pd.read_csv('T_ONTIME_MARKETING_May.csv')
flight_data_df.head(5)
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 1  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 2  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 3  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 4  2022        2      5             1            7  5/1/2022 12:00:00 AM
#
#   MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN  ...  \
# 0                 AA                AA              10140    ABQ  ...
# 1                 AA                AA              10140    ABQ  ...
# 2                 AA                AA              10140    ABQ  ...
# 3                 AA                AA              10140    ABQ  ...
# 4                 AA                AA              10140    ABQ  ...
#
#   DIVERTED ACTUAL_ELAPSED_TIME AIR_TIME  FLIGHTS  DISTANCE CARRIER_DELAY  \
# 0      0.0               104.0     71.0      1.0     569.0           NaN
# 1      0.0                97.0     72.0      1.0     569.0           NaN
# 2      0.0                98.0     73.0      1.0     569.0           NaN
# 3      0.0               110.0     73.0      1.0     569.0           NaN
# 4      0.0                93.0     72.0      1.0     569.0           NaN
#
#   WEATHER_DELAY NAS_DELAY SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0           NaN       NaN            NaN                  NaN
# 1           NaN       NaN            NaN                  NaN
# 2           NaN       NaN            NaN                  NaN
# 3           NaN       NaN            NaN                  NaN
# 4           NaN       NaN            NaN                  NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### i. Drop  Columns

# %% [markdown]
# >Drop unwanted columns to reduce the data size and improve data readability.
# Columns that I will not be using for this project are  as follows:
#
#
# >-    ORIGIN_AIRPORT_ID
# >-    ACTUAL_ELAPSED_TIME
# >-    AIR_TIME
# >-    FLIGHTS
# >-    ORIGIN_WAC
# >-    DEST_AIRPORT_ID
# >-    DEST_WAC
# >-    AIR_TIME

# %%
flight_data_df = flight_data_df.drop(columns=['ORIGIN_AIRPORT_ID','ACTUAL_ELAPSED_TIME','AIR_TIME','FLIGHTS',
                          'ORIGIN_WAC','DEST_AIRPORT_ID','DEST_WAC','AIR_TIME'])
flight_data_df.head(5)
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 1  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 2  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 3  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 4  2022        2      5             1            7  5/1/2022 12:00:00 AM
#
#   MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME  ...  \
# 0                 AA                AA    ABQ  Albuquerque, NM  ...
# 1                 AA                AA    ABQ  Albuquerque, NM  ...
# 2                 AA                AA    ABQ  Albuquerque, NM  ...
# 3                 AA                AA    ABQ  Albuquerque, NM  ...
# 4                 AA                AA    ABQ  Albuquerque, NM  ...
#
#   ARR_DELAY_NEW CANCELLED CANCELLATION_CODE DIVERTED DISTANCE CARRIER_DELAY  \
# 0           0.0       0.0               NaN      0.0    569.0           NaN
# 1           0.0       0.0               NaN      0.0    569.0           NaN
# 2           0.0       0.0               NaN      0.0    569.0           NaN
# 3           0.0       0.0               NaN      0.0    569.0           NaN
# 4           0.0       0.0               NaN      0.0    569.0           NaN
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0            NaN        NaN             NaN                  NaN
# 1            NaN        NaN             NaN                  NaN
# 2            NaN        NaN             NaN                  NaN
# 3            NaN        NaN             NaN                  NaN
# 4            NaN        NaN             NaN                  NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# #### ii. Look for Duplicates

# %% [markdown]
# >Duplicates cause inconsistent results when dealing with statistics. Hence dropping duplicate rows.

# %%
print('Dataframe before dropping duplicates :', flight_data_df.shape)
flight_data_df = flight_data_df.drop_duplicates() # 1,389 rows dropped
print('Dataframe after dropping duplicates :',flight_data_df.shape)
# Out:
# Dataframe before dropping duplicates : (602950, 32)
# Dataframe after dropping duplicates : (601561, 32)

# %% [markdown]
# #### iii. Replace values in a column

# %% [markdown]
# > Cancellation code is represented as A, B, C and D, which is not very informative.
# The BTS website provided details on this code as follows:
#
#     - A Carrier
#
#     - B Weather
#
#     - C National Air System
#
#     - D Security

# %%
flight_data_df.CANCELLATION_CODE = np.where(flight_data_df.CANCELLATION_CODE=='A', 'Carrier',
                                 np.where(flight_data_df.CANCELLATION_CODE=='B', 'Weather',
                                          np.where(flight_data_df.CANCELLATION_CODE=='C', 'National Air System',
                                                   np.where(flight_data_df.CANCELLATION_CODE=='D', 'Security',''))))

flight_data_df.groupby(['CANCELLATION_CODE'])['CANCELLATION_CODE'].count().sort_index()
# Out:
# CANCELLATION_CODE
#                        590957
# Carrier                  4902
# National Air System      1394
# Security                    1
# Weather                  4307
# Name: CANCELLATION_CODE, dtype: int64

# %% [markdown]
# #### iv. Rename Column

# %% [markdown]
# >To make more sense of the information in cancellation_code, replacing the column to cancellation reason.

# %%
flight_data_df = flight_data_df.rename(columns={"CANCELLATION_CODE": "CANCELLATION_REASON"}, errors="raise")
flight_data_df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'ORIGIN_CITY_NAME',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'ARR_DELAY_NEW',
#        'CANCELLED', 'CANCELLATION_REASON', 'DIVERTED', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY'],
#       dtype='object')

# %% [markdown]
# #### v. Add new columns

# %% [markdown]
# ##### STATUS

# %%
#Adding a new column 'STATUS' that tells the status of a flight 
flight_data_df['STATUS'] = ''
 
flight_data_df.STATUS = np.where(flight_data_df.CANCELLED==1, 'Cancelled',
                                 np.where(flight_data_df.DIVERTED==1, 'Diverted',
                                          np.where(flight_data_df.ARR_DELAY<=15, 'On-Time',
                                                   np.where(flight_data_df.ARR_DELAY>15, 'Delayed',''))))
flight_data_df.groupby(['STATUS'])['STATUS'].count().sort_index()
# Out:
# STATUS
# Cancelled     10604
# Delayed      119624
# Diverted       1581
# On-Time      469752
# Name: STATUS, dtype: int64

# %% [markdown]
# ##### DELAYED

# %% [markdown]
# >As a step to data reduction, I will be considering flights arriving 15 minutes or later as delayed

# %%
#Creating a new column 'DELAYED'. A flag that represents if a flight was delayed. Similar to CANCELLED and DIVERTED 

flight_data_df.loc[(flight_data_df['ARR_DELAY']>15), 'DELAYED'] = True
flight_data_df.loc[(flight_data_df['ARR_DELAY']<=15), 'DELAYED'] = False

flight_data_df.groupby(['DELAYED'])['DELAYED'].count().sort_index()
# Out:
# DELAYED
# False    469752
# True     119624
# Name: DELAYED, dtype: int64

# %% [markdown]
# ##### DELAY REASON

# %%
#Adding a new column 'DELAY_REASON' that tells the reason for a flight getting delayed 
#Using the newly created DELAYED flag and the available columns for each type of delay to create one column with the delay reason.

flight_data_df['DELAY_REASON'] = np.where(((flight_data_df.DELAYED==True) & (flight_data_df.CARRIER_DELAY != 0)), 'Carrier',
                                          np.where(((flight_data_df.DELAYED==True) & (flight_data_df.LATE_AIRCRAFT_DELAY != 0)), 'LateAircraft',
                                                   np.where(((flight_data_df.DELAYED==True) & (flight_data_df.WEATHER_DELAY != 0)), 'Weather',
                                                            np.where(((flight_data_df.DELAYED==True) & (flight_data_df.NAS_DELAY != 0)), 'NAS',
                                                                     np.where(((flight_data_df.DELAYED==True) & (flight_data_df.SECURITY_DELAY != 0)), 'Security','')))))

flight_data_df.groupby(['DELAY_REASON'])['DELAY_REASON'].count().sort_index()
# Out:
# DELAY_REASON
#                 481937
# Carrier          72453
# LateAircraft     25504
# NAS              17384
# Security           131
# Weather           4152
# Name: DELAY_REASON, dtype: int64

# %% [markdown]
# #### vi. Implementing arithmetic functions for statistical analysis

# %%
# Create a new dataframe with total number of flights per operating carrier to calculate the % 

flight_totals = flight_data_df.value_counts(subset=['OP_UNIQUE_CARRIER']).reset_index() #Get total flights per operating carrier
flight_totals_df = pd.DataFrame(flight_totals) # Convert to dataframe
flight_totals_df.columns = ['OP_UNIQUE_CARRIER','TOTAL'] # Assign Column names
flight_totals_df['PERCENTAGE'] = round(flight_totals_df.TOTAL/flight_totals_df.TOTAL.sum()*100,2) #Calculate the percentage

flight_totals_df = flight_totals_df.sort_values('PERCENTAGE',ascending=False) #Sort by percentage (descending)
flight_totals_df.head(5)
# Out:
#   OP_UNIQUE_CARRIER   TOTAL  PERCENTAGE
# 0                WN  107950       17.94
# 1                DL   76021       12.64
# 2                AA   71471       11.88
# 3                OO   66615       11.07
# 4                UA   53535        8.90

# %%
# Calculate percentage by carrier and flight status   
flight_status = flight_data_df.value_counts(subset=['OP_UNIQUE_CARRIER','STATUS']).reset_index() #Get total flights per operating carrier and status 
flight_status_df = pd.DataFrame(flight_status) #create a dataframe
flight_status_df.columns = ['OP_UNIQUE_CARRIER','STATUS', 'COUNT'] #Add column names
flight_status_df = flight_status_df.sort_values('OP_UNIQUE_CARRIER') #Sort by operating carrier

flight_status_df['PERCENTAGE'] = ''
            
for index, row in flight_status_df.iterrows():
    tot = flight_totals.loc[flight_totals.OP_UNIQUE_CARRIER==row.OP_UNIQUE_CARRIER].TOTAL.values #Calculate total per operating carrier to get the status percentage 
    val = (row.COUNT/tot * 100)   
    flight_status_df.at[index,'PERCENTAGE'] = round(val[0].astype(float),2) #Calculate the percentage

flight_status_df.head(10)
# Out:
#    OP_UNIQUE_CARRIER     STATUS  COUNT PERCENTAGE
# 33                9E    Delayed   3113      15.33
# 48                9E  Cancelled    542       2.67
# 74                9E   Diverted     35       0.17
# 8                 9E    On-Time  16613      81.83
# 41                AA  Cancelled    973       1.36
# 56                AA   Diverted    215        0.3
# 3                 AA    On-Time  55403      77.52
# 11                AA    Delayed  14880      20.82
# 47                AS  Cancelled    608       3.12
# 10                AS    On-Time  15502      79.49

# %%
#Create a new dataframe with the percentage by origin airport and status
flight_origin_totals = flight_data_df.value_counts(subset=['ORIGIN']).reset_index() #get the counts by origin
flight_origin_totals_df = pd.DataFrame(flight_origin_totals) #create a dataframe
flight_origin_totals_df.columns = ['ORIGIN','TOTAL'] #Add column names
flight_origin_totals_df['PERCENTAGE'] = round(flight_origin_totals_df.TOTAL/flight_origin_totals_df.TOTAL.sum()*100,2) #Calculate the percentage by origin airport
 

origin_airport_delays = flight_data_df.value_counts(subset=['ORIGIN','STATUS']).reset_index() #get counts by origin and status
origin_airport_df = pd.DataFrame(origin_airport_delays) #create a dataframe
origin_airport_df.columns = ['ORIGIN','STATUS', 'COUNT'] #add column names
origin_airport_df = origin_airport_df.sort_values('ORIGIN') #sort by origin
origin_airport_df['PERCENTAGE'] = ''
            
for index, row in origin_airport_df.iterrows():
    tot = flight_origin_totals.loc[flight_origin_totals.ORIGIN==row.ORIGIN].TOTAL.values #get totals per origin & status
    val = (row.COUNT/tot * 100)   
    origin_airport_df.at[index,'PERCENTAGE'] = round(val[0].astype(float),2) #calulate the percentage

origin_airport_df = origin_airport_df.sort_values('PERCENTAGE',ascending=False) #sort by percentage descending
 
origin_airport_df.head(10)
# Out:
#      ORIGIN   STATUS  COUNT PERCENTAGE
# 770     GST  On-Time     12      100.0
# 1208    STC  On-Time      1      100.0
# 385     LWS  On-Time     95      96.94
# 623     BGM  On-Time     30      96.77
# 470     DRT  On-Time     60      96.77
# 517     PLN  On-Time     51      96.23
# 488     MCW  On-Time     55      94.83
# 490     FOD  On-Time     55      94.83
# 515     TBN  On-Time     51      94.44
# 529     LAR  On-Time     50      94.34

# %% [markdown]
# #### vii. NULL check

# %%
#Looking for null values to further reduce the data size.
flight_data_df.isnull().sum()
# Out:
# YEAR                        0
# QUARTER                     0
# MONTH                       0
# DAY_OF_MONTH                0
# DAY_OF_WEEK                 0
# FL_DATE                     0
# MKT_UNIQUE_CARRIER          0
# OP_UNIQUE_CARRIER           0
# ORIGIN                      0
# ORIGIN_CITY_NAME            0
# ORIGIN_STATE_ABR            0
# ORIGIN_STATE_NM             0
# DEST                        0
# DEST_CITY_NAME              0
# DEST_STATE_ABR              0
# DEST_STATE_NM               0
# DEP_DELAY               10201
# DEP_DELAY_NEW           10201
# TAXI_OUT                10558
# TAXI_IN                 10769
# ARR_TIME                10769
# ARR_DELAY               12185
# ARR_DELAY_NEW           12185
# CANCELLED                   0
# CANCELLATION_REASON         0
# DIVERTED                    0
# DISTANCE                    0
# CARRIER_DELAY          477611
# WEATHER_DELAY          477611
# NAS_DELAY              477611
# SECURITY_DELAY         477611
# LATE_AIRCRAFT_DELAY    477611
# STATUS                      0
# DELAYED                 12185
# DELAY_REASON                0
# dtype: int64

# %% [markdown]
# >Based on the above, it doesn't appear there are any null rows that are irrelevant.
# Status is a significant column that tells if there are any flights with no relevant status. All flights are now categorized under On-Time, Delayed, Cancelled or Diverted.

# %% [markdown]
# >The final flat file dataset is as follows:

# %%
print(flight_data_df.columns)
flight_data_df.head(5)
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'ORIGIN_CITY_NAME',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'ARR_DELAY_NEW',
#        'CANCELLED', 'CANCELLATION_REASON', 'DIVERTED', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'STATUS', 'DELAYED', 'DELAY_REASON'],
#       dtype='object')
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 1  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 2  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 3  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 4  2022        2      5             1            7  5/1/2022 12:00:00 AM
#
#   MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME  ... DIVERTED  \
# 0                 AA                AA    ABQ  Albuquerque, NM  ...      0.0
# 1                 AA                AA    ABQ  Albuquerque, NM  ...      0.0
# 2                 AA                AA    ABQ  Albuquerque, NM  ...      0.0
# 3                 AA                AA    ABQ  Albuquerque, NM  ...      0.0
# 4                 AA                AA    ABQ  Albuquerque, NM  ...      0.0
#
#   DISTANCE CARRIER_DELAY WEATHER_DELAY NAS_DELAY SECURITY_DELAY  \
# 0    569.0           NaN           NaN       NaN            NaN
# 1    569.0           NaN           NaN       NaN            NaN
# 2    569.0           NaN           NaN       NaN            NaN
# 3    569.0           NaN           NaN       NaN            NaN
# 4    569.0           NaN           NaN       NaN            NaN
#
#    LATE_AIRCRAFT_DELAY   STATUS  DELAYED  DELAY_REASON
# 0                  NaN  On-Time    False
# 1                  NaN  On-Time    False
# 2                  NaN  On-Time    False
# 3                  NaN  On-Time    False
# 4                  NaN  On-Time    False
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Ethical implications:
# >BTS data - Flat File
# I do not see any ethical implications for this dataset as it is from a federal government source and is made accessible to public. The only concern I have is that, the dataset I am referring to is old and it's possible the trend has changed over time. The reason for using old dataset is because I need the flight diversion information which I was only able to find for the year 2022.

# %% [markdown]
# ### Conclusion:
# > As a part of this milestone, the following Data Transformation steps have been performed.
# >1. Dropped columns
# >2. Dropped duplicate rows
# >3. Replaced values in a dataframe column
# >4. Renamed a column
# >5. Added new columns to the dataframe
# >6. Implemented arithmetic functions for statistical analysis
# >7. Performed null check to drop rows with null values.

# %% [markdown]
# ## Milestone 3 - Cleaning/Formatting Website Data

# %% [markdown]
# >Flat File - Website:
# The flat file has a column for diverted flights but does not have any information on the cause for diversion. I would like to look up the reason for a flight being diverted. The website and flat file can be matched on flight date, origin and destination to lookup diverted flight information.
# Flat file has many to many relation with the Website. We will need to pass the flight date and the origin and destination city to the website to get flight diversion details for a particular date and route.

# %%
url = 'https://www.diverted.eu/' #Website with diverted flight information

# %%
# Parsing HTML using BeautifulSoup
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# %%
#Parse HTML for the diverted data table
flight_diverted_table = soup.findAll("table", { 'id' : 'tablepress-current_month' })
flight_diverted_table
# Out:
# [<table class="tablepress tablepress-id-current_month tablepress-responsive" id="tablepress-current_month">
#  <thead>
#  <tr class="row-1 odd">
#  <th class="column-1">Date</th><th class="column-2">Airlines/Operator</th><th class="column-3">Flight number</th><th class="column-4">Departure airport</th><th class="column-5">Destination airport</th><th class="column-6">Diverted to</th><th class="column-7">Emergency code</th><th class="column-8">Alleged reason</th><th class="column-9">Aircraft</th><th class="column-10">Registration</th>
#  </tr>
#  </thead>
#  <tbody class="row-hover">
#  <tr class="row-2 even">
#  <td class="column-1">20.07.2022</td><td class="column-2">Go First</td><td class="column-3">G8151 / GOW151</td><td class="column-4">Delhi</td><td class="column-5">Guwahati</td><td class="column-6">Jaipur</td><td class="column-7"></td><td class="column-8">cracked windshield</td><td class="column-9">Airbus A320-271N</td><td class="column-10">VT-WGP</td>
#  </tr>
#  <tr class="row-3 odd">
#  <td class="column-1">20.07.2022</td><td class="column-2">Wizz Air</td><td class="column-3">W65058 / WZZ101S</td><td class="column-4">Bari</td><td class="column-5">Krakow</td><td class="column-6">Budapest</td><td class="column-7"></td><td class="column-8">bomb threat</td><td class="column-9">Airbus A321-271NX</td><td class="column-10">HA-LGA</td>
#  </tr>
#  <tr class="row-4 even">
#  <td class="column-1">19.07.2022</td><td class="column-2">Go First</td><td class="column-3">G8386 / GOW386</td><td class="column-4">Mumbai</td><td class="column-5">Leh</td><td class="column-6">Delhi</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-271N</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/vt-wga/" rel="noopener" target="_blank">VT-WGA</a></td>
#  </tr>
#  <tr class="row-5 odd">
#  <td class="column-1">19.07.2022</td><td class="column-2">Go First</td><td class="column-3">G86202 / GOW6202</td><td class="column-4">Srinagar</td><td class="column-5">Delhi</td><td class="column-6">Srinagar</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-271N</td><td class="column-10">VT-WJG</td>
#  </tr>
#  <tr class="row-6 even">
#  <td class="column-1">19.07.2022</td><td class="column-2">LOT</td><td class="column-3">LO6297 / LOT6297</td><td class="column-4">Prague</td><td class="column-5">Zanzibar</td><td class="column-6">Warsaw</td><td class="column-7"></td><td class="column-8">brakes issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/sp-lsb/" rel="noopener" target="_blank">SP-LSB</a></td>
#  </tr>
#  <tr class="row-7 odd">
#  <td class="column-1">19.07.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA1849 / AAL1849</td><td class="column-4">Charlotte</td><td class="column-5">Portland</td><td class="column-6">Charlotte</td><td class="column-7"></td><td class="column-8">mechanical issue</td><td class="column-9">Airbus A321-211</td><td class="column-10">N171US</td>
#  </tr>
#  <tr class="row-8 even">
#  <td class="column-1">19.07.2022</td><td class="column-2">Condor</td><td class="column-3">DE1439 / CFG2EC</td><td class="column-4">Lanzarote</td><td class="column-5">Hamburg</td><td class="column-6">Lanzarote</td><td class="column-7">7700</td><td class="column-8">possible engine issue</td><td class="column-9">Boeing 757-330</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/d-aboa/"' target="_blank">D-ABOA</a></td>
#  </tr>
#  <tr class="row-9 odd">
#  <td class="column-1">18.07.2022</td><td class="column-2">Transavia</td><td class="column-3">HV5908 / TRA89E</td><td class="column-4">Heraklion</td><td class="column-5">Eindhoven</td><td class="column-6">Athens</td><td class="column-7"></td><td class="column-8">odor on board</td><td class="column-9">Boeing 737-8K2</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/ph-hxa/" rel="noopener" target="_blank">PH-HXA</a></td>
#  </tr>
#  <tr class="row-10 even">
#  <td class="column-1">18.07.2022</td><td class="column-2">VivaAerobus</td><td class="column-3">VB4081 / VIV4081</td><td class="column-4">Tijuana</td><td class="column-5">Monterrey</td><td class="column-6">Hermosillo</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Airbus A321-271NX</td><td class="column-10">XA-VXA</td>
#  </tr>
#  <tr class="row-11 odd">
#  <td class="column-1">18.07.2022</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL115 / DAL115</td><td class="column-4">Paris</td><td class="column-5">Seattle</td><td class="column-6">Minneapolis</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Airbus A330-323</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/n815nw/"' target="_blank">N815NW</a></td>
#  </tr>
#  <tr class="row-12 even">
#  <td class="column-1">17.07.2022</td><td class="column-2">Southwest Airlines</td><td class="column-3">WN2208 / SWA2208</td><td class="column-4">Phoenix</td><td class="column-5">Chicago</td><td class="column-6">Phoenix</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-7H4</td><td class="column-10">N474WN</td>
#  </tr>
#  <tr class="row-13 odd">
#  <td class="column-1">17.07.2022</td><td class="column-2">KLM</td><td class="column-3">KL992 / KLM992</td><td class="column-4">London</td><td class="column-5">Amsterdam</td><td class="column-6">London</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Embraer E190STD</td><td class="column-10">PH-EXV</td>
#  </tr>
#  <tr class="row-14 even">
#  <td class="column-1">16.07.2022</td><td class="column-2">IndiGo</td><td class="column-3">6E1406 / IGO1406</td><td class="column-4">Sharjah</td><td class="column-5">Hyderabad</td><td class="column-6">Karachi</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-271N</td><td class="column-10">VT-IJK</td>
#  </tr>
#  <tr class="row-15 odd">
#  <td class="column-1">16.07.2022</td><td class="column-2">Air India Express</td><td class="column-3">IX355 / AXB355</td><td class="column-4">Kozhikode</td><td class="column-5">Dubai</td><td class="column-6">Muscat</td><td class="column-7"></td><td class="column-8">smell in cabin</td><td class="column-9">Boeing 737-8HG</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/vt-axx/" rel="noopener" target="_blank">VT-AXX</a></td>
#  </tr>
#  <tr class="row-16 even">
#  <td class="column-1">16.07.2022</td><td class="column-2">Eurowings Discover</td><td class="column-3">4Y7 / OCN7</td><td class="column-4">Puerto Plata</td><td class="column-5">Frankfurt</td><td class="column-6">Dusseldorf</td><td class="column-7"></td><td class="column-8">pressurisation issue</td><td class="column-9">Airbus A330-343</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/d-aika/" rel="noopener" target="_blank">D-AIKA</a></td>
#  </tr>
#  <tr class="row-17 odd">
#  <td class="column-1">15.07.2022</td><td class="column-2">LATAM Airlines</td><td class="column-3">LA3457 / TAM3457</td><td class="column-4">Florianopolis</td><td class="column-5">Sao Paulo</td><td class="column-6">Florianopolis</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A320-232</td><td class="column-10">PR-MBH</td>
#  </tr>
#  <tr class="row-18 even">
#  <td class="column-1">15.07.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA2638 / UAL2638</td><td class="column-4">Portland</td><td class="column-5">New York</td><td class="column-6">Green Bay</td><td class="column-7"></td><td class="column-8">smoke in cockpit</td><td class="column-9">Boeing 737-724</td><td class="column-10">N13720</td>
#  </tr>
#  <tr class="row-19 odd">
#  <td class="column-1">15.07.2022</td><td class="column-2">Enter Air</td><td class="column-3">E45515 / ENT5515</td><td class="column-4">Warsaw</td><td class="column-5">Espargos</td><td class="column-6">Tenerife</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737 MAX 8</td><td class="column-10">SP-EXA</td>
#  </tr>
#  <tr class="row-20 even">
#  <td class="column-1">14.07.2022</td><td class="column-2">IndiGo</td><td class="column-3">6E859 / IGO859</td><td class="column-4">Delhi</td><td class="column-5">Vadodara</td><td class="column-6">Jaipur</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-271N</td><td class="column-10">VT-ITP</td>
#  </tr>
#  <tr class="row-21 odd">
#  <td class="column-1">14.07.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA629 / AAL629</td><td class="column-4">New York</td><td class="column-5">Miami</td><td class="column-6">Charlotte</td><td class="column-7">7700</td><td class="column-8">potential mechanical issue</td><td class="column-9">Boeing 737-823</td><td class="column-10">N818NN</td>
#  </tr>
#  <tr class="row-22 even">
#  <td class="column-1">14.07.2022</td><td class="column-2">Royal Air Maroc</td><td class="column-3">AT851 / RAM851W</td><td class="column-4">Rotterdam</td><td class="column-5">Casablanca</td><td class="column-6">Amsterdam</td><td class="column-7"></td><td class="column-8">flaps issue</td><td class="column-9">Boeing 737-8B6</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/cn-rnp/" rel="noopener" target="_blank">CN-RNP</a></td>
#  </tr>
#  <tr class="row-23 odd">
#  <td class="column-1">12.07.2022</td><td class="column-2">Lufthansa</td><td class="column-3">LH1311 / DLH8WT</td><td class="column-4">Luqa</td><td class="column-5">Frankfurt</td><td class="column-6">Palermo</td><td class="column-7">7700</td><td class="column-8">engine issue</td><td class="column-9">Airbus A321-131</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/d-airl/"' target="_blank">D-AIRL</a></td>
#  </tr>
#  <tr class="row-24 even">
#  <td class="column-1">12.07.2022</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL123 / DAL123</td><td class="column-4">Edinburgh</td><td class="column-5">Boston</td><td class="column-6">Shannon</td><td class="column-7">7700</td><td class="column-8">hydraulic issue</td><td class="column-9">Boeing 767-332(ER)</td><td class="column-10">N193DN</td>
#  </tr>
#  <tr class="row-25 odd">
#  <td class="column-1">11.07.2022</td><td class="column-2">Nordstar</td><td class="column-3">Y7217 / TYA217</td><td class="column-4">Krasnoyarsk</td><td class="column-5">Norilsk</td><td class="column-6">Krasnoyarsk</td><td class="column-7"></td><td class="column-8">cargo smoke indication</td><td class="column-9">Boeing 737-8AS</td><td class="column-10">RA-73252</td>
#  </tr>
#  <tr class="row-26 even">
#  <td class="column-1">11.07.2022</td><td class="column-2">Ryanair</td><td class="column-3">FR8397 / RYR7NH</td><td class="column-4">Jerez</td><td class="column-5">London</td><td class="column-6">Bordeaux</td><td class="column-7">7700</td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-8AS</td><td class="column-10">EI-EKS</td>
#  </tr>
#  <tr class="row-27 odd">
#  <td class="column-1">11.07.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA3532 / RPA3532</td><td class="column-4">Nashville</td><td class="column-5">New York</td><td class="column-6">Greensboro</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Embraer E170SE</td><td class="column-10">N650RW</td>
#  </tr>
#  <tr class="row-28 even">
#  <td class="column-1">11.07.2022</td><td class="column-2">Binter Canarias</td><td class="column-3">NT784 / IBB55AB</td><td class="column-4">Lanzarote</td><td class="column-5">Tenerife</td><td class="column-6">Lanzarote</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">ATR 72-600</td><td class="column-10">EC-NQR</td>
#  </tr>
#  <tr class="row-29 odd">
#  <td class="column-1">11.07.2022</td><td class="column-2">Scoot</td><td class="column-3">TR9 / TGW9</td><td class="column-4">Perth</td><td class="column-5">Singapore</td><td class="column-6">Perth</td><td class="column-7"></td><td class="column-8">tyre/landing gear issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">9V-OJA</td>
#  </tr>
#  <tr class="row-30 even">
#  <td class="column-1">10.07.2022</td><td class="column-2">LOT</td><td class="column-3">LO614 / LOT6ER</td><td class="column-4">Zagreb</td><td class="column-5">Warsaw</td><td class="column-6">Zagreb</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Embraer E175LR</td><td class="column-10">SP-LIM</td>
#  </tr>
#  <tr class="row-31 odd">
#  <td class="column-1">09.07.2022</td><td class="column-2">Azul Linhas Aereas</td><td class="column-3">AD4342 / AZU4342</td><td class="column-4">Cuiaba</td><td class="column-5">Porto Velho</td><td class="column-6">Cuiaba</td><td class="column-7"></td><td class="column-8">cargo door indication</td><td class="column-9">Airbus A320-253N</td><td class="column-10">PR-YRS</td>
#  </tr>
#  <tr class="row-32 even">
#  <td class="column-1">09.07.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA2930 / AAL2930</td><td class="column-4">Las Vegas</td><td class="column-5">Charlotte</td><td class="column-6">Phoenix</td><td class="column-7"></td><td class="column-8">smoke in cabin</td><td class="column-9">Airbus A321-231</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n552uw/" rel="noopener" target="_blank">N552UW</a></td>
#  </tr>
#  <tr class="row-33 odd">
#  <td class="column-1">09.07.2022</td><td class="column-2">Korean Air</td><td class="column-3">KE9956 / KAL9956</td><td class="column-4">Istanbul</td><td class="column-5">Seoul</td><td class="column-6">Baku</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A330-223</td><td class="column-10">HL8228</td>
#  </tr>
#  <tr class="row-34 even">
#  <td class="column-1">09.07.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA2749 / UAL2749</td><td class="column-4">Victorville</td><td class="column-5">Chicago</td><td class="column-6">Los Angeles</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 777-222(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n204ua/" rel="noopener" target="_blank">N204UA</a></td>
#  </tr>
#  <tr class="row-35 odd">
#  <td class="column-1">09.07.2022</td><td class="column-2">Iraqi Airways</td><td class="column-3">IA145 / IAW145</td><td class="column-4">Arbil</td><td class="column-5">Cairo</td><td class="column-6">Baghdad</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 737-81Z</td><td class="column-10">YI-ASH</td>
#  </tr>
#  <tr class="row-36 even">
#  <td class="column-1">08.07.2022</td><td class="column-2">Smartavia</td><td class="column-3">5N861 / AUL861</td><td class="column-4">Sochi</td><td class="column-5">Omsk</td><td class="column-6">Ufa</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 737-89P</td><td class="column-10">RA-73659</td>
#  </tr>
#  <tr class="row-37 odd">
#  <td class="column-1">08.07.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA1580 / AAL1580</td><td class="column-4">Chicago</td><td class="column-5">Buffalo</td><td class="column-6">Grand Rapids</td><td class="column-7"></td><td class="column-8">smoke in cockpit</td><td class="column-9">Boeing 737-823</td><td class="column-10">N939NN</td>
#  </tr>
#  <tr class="row-38 even">
#  <td class="column-1">08.07.2022</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL1073 / DAL1073</td><td class="column-4">Salt Lake City</td><td class="column-5">Indianapolis</td><td class="column-6">Salt Lake City</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-212</td><td class="column-10">N371NW</td>
#  </tr>
#  <tr class="row-39 odd">
#  <td class="column-1">06.07.2022</td><td class="column-2">Ural Airlines</td><td class="column-3">U62425 / SVR2425</td><td class="column-4">Moscow</td><td class="column-5">Khudzhand</td><td class="column-6">Moscow</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A321-231</td><td class="column-10">RA-73843</td>
#  </tr>
#  <tr class="row-40 even">
#  <td class="column-1">06.07.2022</td><td class="column-2">Aer Lingus</td><td class="column-3">EI104 / EIN104</td><td class="column-4">New York</td><td class="column-5">Dublin</td><td class="column-6">New York</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Airbus A330-302</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/ei-duz/"' target="_blank">EI-DUZ</a></td>
#  </tr>
#  <tr class="row-41 odd">
#  <td class="column-1">06.07.2022</td><td class="column-2">EasyJet</td><td class="column-3">U27169 / EZY23KG</td><td class="column-4">Liverpool</td><td class="column-5">Tenerife</td><td class="column-6">Lisbon</td><td class="column-7"></td><td class="column-8">disruptive passenger</td><td class="column-9">Airbus A320-251N</td><td class="column-10">G-UZLD</td>
#  </tr>
#  <tr class="row-42 even">
#  <td class="column-1">05.07.2022</td><td class="column-2">Porter Airlines</td><td class="column-3">PD246 / POE246</td><td class="column-4">Toronto</td><td class="column-5">Thunder Bay</td><td class="column-6">Toronto</td><td class="column-7"></td><td class="column-8">odor on board</td><td class="column-9">De Havilland Canada Dash 8-400</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/c-glqb/"' target="_blank">C-GLQB</a></td>
#  </tr>
#  <tr class="row-43 odd">
#  <td class="column-1">05.07.2022</td><td class="column-2">SpiceJet</td><td class="column-3">SG11 / SEJ011</td><td class="column-4">Delhi</td><td class="column-5">Dubai</td><td class="column-6">Karachi</td><td class="column-7"></td><td class="column-8">suspected fuel leak</td><td class="column-9">Boeing 737 MAX 8</td><td class="column-10">VT-MXG</td>
#  </tr>
#  <tr class="row-44 even">
#  <td class="column-1">04.07.2022</td><td class="column-2">Swoop</td><td class="column-3">WO264 / WSW264</td><td class="column-4">Edmonton</td><td class="column-5">Halifax</td><td class="column-6">Edmonton</td><td class="column-7"></td><td class="column-8">tyre issue</td><td class="column-9">Boeing 737-8CT</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/c-gxrw/"' target="_blank">C-GXRW</a></td>
#  </tr>
#  <tr class="row-45 odd">
#  <td class="column-1">04.07.2022</td><td class="column-2">Aeroflot</td><td class="column-3">SU6391 / SDM6391</td><td class="column-4">Moscow</td><td class="column-5">Magnitogorsk</td><td class="column-6">Moscow</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Sukhoi Superjet 100-95B</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/ra-89099/"' target="_blank">RA-89099</a></td>
#  </tr>
#  <tr class="row-46 even">
#  <td class="column-1">04.07.2022</td><td class="column-2">Etihad</td><td class="column-3">EY65 / ETD65</td><td class="column-4">Abu Dhabi</td><td class="column-5">Moscow</td><td class="column-6">Abu Dhabi</td><td class="column-7">7700</td><td class="column-8">smell on board</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">A6-BLQ</td>
#  </tr>
#  <tr class="row-47 odd">
#  <td class="column-1">04.07.2022</td><td class="column-2">Loganair</td><td class="column-3">LM660 / LOG46SP</td><td class="column-4">Liverpool</td><td class="column-5">Londonderry</td><td class="column-6">Liverpool</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Embraer ERJ-145MP</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-sajo/" rel="noopener" target="_blank">G-SAJO</a></td>
#  </tr>
#  <tr class="row-48 even">
#  <td class="column-1">03.07.2022</td><td class="column-2">Air Canada</td><td class="column-3">AC8543 / JZA543</td><td class="column-4">Montreal</td><td class="column-5">Regina</td><td class="column-6">Montreal</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Embraer E175SU</td><td class="column-10">C-FRQN</td>
#  </tr>
#  <tr class="row-49 odd">
#  <td class="column-1">03.07.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA885 / UAL885</td><td class="column-4">Rome</td><td class="column-5">Washington</td><td class="column-6">London</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Boeing 777-224(ER)</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/n7602/"' target="_blank">N76021</a></td>
#  </tr>
#  <tr class="row-50 even">
#  <td class="column-1">03.07.2022</td><td class="column-2">TAAG Angola Airlines</td><td class="column-3">DT577 / DTA577</td><td class="column-4">Luanda</td><td class="column-5">Johannesburg</td><td class="column-6">Lubango</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Boeing 737-7M2</td><td class="column-10">D2-TBJ</td>
#  </tr>
#  <tr class="row-51 odd">
#  <td class="column-1">02.07.2022</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL2187 / DAL2187</td><td class="column-4">New York</td><td class="column-5">Orlando</td><td class="column-6">Charleston</td><td class="column-7"></td><td class="column-8">cargo smoke indication</td><td class="column-9">Airbus A321-211</td><td class="column-10">N319DN</td>
#  </tr>
#  <tr class="row-52 even">
#  <td class="column-1">02.07.2022</td><td class="column-2">SpiceJet</td><td class="column-3">SG2962 / SEJ2962</td><td class="column-4">Delhi</td><td class="column-5">Jabalpur</td><td class="column-6">Delhi</td><td class="column-7"></td><td class="column-8">smoke in cabin</td><td class="column-9">De Havilland Canada Dash 8-400</td><td class="column-10"></td>
#  </tr>
#  <tr class="row-53 odd">
#  <td class="column-1">02.07.2022</td><td class="column-2">British Airways</td><td class="column-3">BA670 / BAW670</td><td class="column-4">London</td><td class="column-5">Bodrum</td><td class="column-6">Frankfurt</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-232</td><td class="column-10">G-EUUK</td>
#  </tr>
#  <tr class="row-54 even">
#  <td class="column-1">02.07.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA1859 / AAL1859</td><td class="column-4">Charlotte</td><td class="column-5">Liberia</td><td class="column-6">Jacksonville</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-823</td><td class="column-10">N938AN</td>
#  </tr>
#  <tr class="row-55 odd">
#  <td class="column-1">02.07.2022</td><td class="column-2">Aeroflot</td><td class="column-3">SU1747 / AFL1747</td><td class="column-4">Yuzhno-Sakhalinsk</td><td class="column-5">Moscow</td><td class="column-6">Novosibirsk</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 777-3M0(ER)</td><td class="column-10">RA-73130</td>
#  </tr>
#  <tr class="row-56 even">
#  <td class="column-1">01.07.2022</td><td class="column-2">Air New Zealand</td><td class="column-3">NZ287 / ANZ287</td><td class="column-4">Christchurch</td><td class="column-5">Shanghai</td><td class="column-6">Auckland</td><td class="column-7"></td><td class="column-8">windshield issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">ZK-NZG</td>
#  </tr>
#  <tr class="row-57 odd">
#  <td class="column-1">01.07.2022</td><td class="column-2">Jet2</td><td class="column-3">LS507 / EXS76XM</td><td class="column-4">Newcastle</td><td class="column-5">Antalya</td><td class="column-6">Newcastle</td><td class="column-7">7700</td><td class="column-8">engine issue</td><td class="column-9">Boeing 737-8MG</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-jzbh/" rel="noopener" target="_blank">G-JZBH</a></td>
#  </tr>
#  <tr class="row-58 even">
#  <td class="column-1">01.07.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA1461 / UAL1461</td><td class="column-4">Orlando</td><td class="column-5">New York</td><td class="column-6">Washington</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-924(ER)</td><td class="column-10">N38459</td>
#  </tr>
#  <tr class="row-59 odd">
#  <td class="column-1">30.06.2022</td><td class="column-2">Nolinor Aviation</td><td class="column-3">N5710 / NRL710</td><td class="column-4">Montreal</td><td class="column-5">Holguin</td><td class="column-6">Jacksonville</td><td class="column-7">7700</td><td class="column-8">cargo smoke indication</td><td class="column-9">Boeing 737-408</td><td class="column-10">C-GGWX</td>
#  </tr>
#  <tr class="row-60 even">
#  <td class="column-1">30.06.2022</td><td class="column-2">British Airways</td><td class="column-3">BA249 / BAW249</td><td class="column-4">London</td><td class="column-5">Rio de Janeiro</td><td class="column-6">Fortaleza</td><td class="column-7"></td><td class="column-8">disruptive passenger</td><td class="column-9">Boeing 787-8 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-zbjm/" rel="noopener" target="_blank">G-ZBJM</a></td>
#  </tr>
#  <tr class="row-61 odd">
#  <td class="column-1">30.06.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA935 / UAL935</td><td class="column-4">London</td><td class="column-5">Los Angeles</td><td class="column-6">London</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">N24979</td>
#  </tr>
#  <tr class="row-62 even">
#  <td class="column-1">29.06.2022</td><td class="column-2">Pegas Fly</td><td class="column-3">EO567 / KAR567</td><td class="column-4">Moscow</td><td class="column-5">Orsk</td><td class="column-6">Moscow</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Embraer E190LR</td><td class="column-10">RA-02741</td>
#  </tr>
#  <tr class="row-63 odd">
#  <td class="column-1">29.06.2022</td><td class="column-2">Etihad</td><td class="column-3">EY100 / ETD47N</td><td class="column-4">New York</td><td class="column-5">Abu Dhabi</td><td class="column-6">Frankfurt</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">A6-BLU</td>
#  </tr>
#  <tr class="row-64 even">
#  <td class="column-1">28.06.2022</td><td class="column-2">Aeromexico</td><td class="column-3">AM652 / AMX652</td><td class="column-4">Guadalajara</td><td class="column-5">Chicago</td><td class="column-6">Guadalajara</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Boeing 737-852</td><td class="column-10">N957AM</td>
#  </tr>
#  <tr class="row-65 odd">
#  <td class="column-1">27.06.2022</td><td class="column-2">TUI Airways</td><td class="column-3">BY216 / TOM5GM</td><td class="column-4">Manchester</td><td class="column-5">Boa Vista</td><td class="column-6">Manchester</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Boeing 767-38A(ER)</td><td class="column-10">G-OBYK</td>
#  </tr>
#  <tr class="row-66 even">
#  <td class="column-1">27.06.2022</td><td class="column-2">Aer Lingus</td><td class="column-3">EI432 / EIN432</td><td class="column-4">Dublin</td><td class="column-5">Milan</td><td class="column-6">Lyon</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Airbus A320-214</td><td class="column-10">EI-EDP</td>
#  </tr>
#  <tr class="row-67 odd">
#  <td class="column-1">27.06.2022</td><td class="column-2">LOT</td><td class="column-3">LO156 / LOT15A</td><td class="column-4">Tel Aviv</td><td class="column-5">Warsaw</td><td class="column-6">Sofia</td><td class="column-7"></td><td class="column-8">cargo smoke indication</td><td class="column-9">Boeing 737-89P</td><td class="column-10">SP-LWC</td>
#  </tr>
#  <tr class="row-68 even">
#  <td class="column-1">27.06.2022</td><td class="column-2">Condor</td><td class="column-3">DE3 / CFG003</td><td class="column-4">Hurghada</td><td class="column-5">Hamburg</td><td class="column-6">Cairo</td><td class="column-7"></td><td class="column-8">spoiler issue</td><td class="column-9">Boeing 757-330</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/d-abof/" rel="noopener" target="_blank">D-ABOF</a></td>
#  </tr>
#  <tr class="row-69 odd">
#  <td class="column-1">26.06.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA1203 / UAL1203</td><td class="column-4">Washington</td><td class="column-5">Oranjestad</td><td class="column-6">Nassau</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-924(ER)</td><td class="column-10">N39418</td>
#  </tr>
#  <tr class="row-70 even">
#  <td class="column-1">26.06.2022</td><td class="column-2">Singapore Airlines</td><td class="column-3">SQ323 / SIA323</td><td class="column-4">Amsterdam</td><td class="column-5">Singapore</td><td class="column-6">Mumbai</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Airbus A350-941</td><td class="column-10">9V-SJA</td>
#  </tr>
#  <tr class="row-71 odd">
#  <td class="column-1">25.06.2022</td><td class="column-2">LATAM Airlines</td><td class="column-3">LA4784 / TAM4784</td><td class="column-4">Sao Paulo</td><td class="column-5">Manaus</td><td class="column-6">Brasilia</td><td class="column-7"></td><td class="column-8">cracked windshield</td><td class="column-9">Boeing 777-32W(ER)</td><td class="column-10">PT-MUD</td>
#  </tr>
#  <tr class="row-72 even">
#  <td class="column-1">25.06.2022</td><td class="column-2">Alaska Airlines</td><td class="column-3">AS393 / ASA393</td><td class="column-4">New York</td><td class="column-5">San Diego</td><td class="column-6">Phoenix</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 737-990(ER)</td><td class="column-10">N402AS</td>
#  </tr>
#  <tr class="row-73 odd">
#  <td class="column-1">25.06.2022</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL3507 / SKW3507</td><td class="column-4">Medford</td><td class="column-5">Salt Lake City</td><td class="column-6">Medford</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Embraer E175LR</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n243sy/" rel="noopener" target="_blank">N243SY</a></td>
#  </tr>
#  <tr class="row-74 even">
#  <td class="column-1">24.06.2022</td><td class="column-2">Ryanair</td><td class="column-3">FR4742 / RYR29QZ</td><td class="column-4">Warsaw</td><td class="column-5">Glasgow</td><td class="column-6">Amsterdam</td><td class="column-7">7700</td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-8AS</td><td class="column-10">SP-RKT</td>
#  </tr>
#  <tr class="row-75 odd">
#  <td class="column-1">24.06.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA5560 / JIA5560</td><td class="column-4">Birmingham</td><td class="column-5">Charlotte</td><td class="column-6">Atlanta</td><td class="column-7"></td><td class="column-8">maintenance issue</td><td class="column-9">Mitsubishi CRJ-702ER</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n531eg/" rel="noopener" target="_blank">N531EG</a></td>
#  </tr>
#  <tr class="row-76 even">
#  <td class="column-1">24.06.2022</td><td class="column-2">Vueling</td><td class="column-3">VY1505 / VLG50AR</td><td class="column-4">Paris</td><td class="column-5">Florence</td><td class="column-6">Bologna</td><td class="column-7"></td><td class="column-8">technical reasons</td><td class="column-9">Airbus A319-112</td><td class="column-10"></td>
#  </tr>
#  <tr class="row-77 odd">
#  <td class="column-1">24.06.2022</td><td class="column-2">Alaska Airlines</td><td class="column-3">AS675 / ASA675</td><td class="column-4">Las Vegas</td><td class="column-5">Seattle</td><td class="column-6">Reno</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-990</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n319as/" rel="noopener" target="_blank">N319AS</a></td>
#  </tr>
#  <tr class="row-78 even">
#  <td class="column-1">24.06.2022</td><td class="column-2">TUI Airways</td><td class="column-3">BY822 / TOM822</td><td class="column-4">Manchester</td><td class="column-5">Dalaman</td><td class="column-6">Manchester</td><td class="column-7"></td><td class="column-8">fumes on board</td><td class="column-9">Boeing 787-8 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-tuib/" rel="noopener" target="_blank">G-TUIB</a></td>
#  </tr>
#  <tr class="row-79 odd">
#  <td class="column-1">23.06.2022</td><td class="column-2">British Airways</td><td class="column-3">BA281 / BAW281</td><td class="column-4">London</td><td class="column-5">Los Angeles</td><td class="column-6">Winnipeg</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 777-300(ER)</td><td class="column-10">G-STBO</td>
#  </tr>
#  <tr class="row-80 even">
#  <td class="column-1">23.06.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA316 / UAL316</td><td class="column-4">Dublin</td><td class="column-5">New York</td><td class="column-6">Dublin</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 757-224</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n33103/" rel="noopener" target="_blank">N33103</a></td>
#  </tr>
#  <tr class="row-81 odd">
#  <td class="column-1">23.06.2022</td><td class="column-2">Air Europa</td><td class="column-3">UX9045 / AEA9045</td><td class="column-4">Tenerife</td><td class="column-5">Madrid</td><td class="column-6">Lanzarote</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-85P</td><td class="column-10">EC-LYR</td>
#  </tr>
#  <tr class="row-82 even">
#  <td class="column-1">23.06.2022</td><td class="column-2">Ryanair</td><td class="column-3">FR5994 / RYR7YD</td><td class="column-4">London</td><td class="column-5">Madrid</td><td class="column-6">Bordeaux</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-8AS</td><td class="column-10">EI-DHH</td>
#  </tr>
#  <tr class="row-83 odd">
#  <td class="column-1">22.06.2022</td><td class="column-2">Air France</td><td class="column-3">AF454 / AFR454</td><td class="column-4">Paris</td><td class="column-5">Sao Paulo</td><td class="column-6">Paris</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 777-328(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/f-gsqh/" rel="noopener" target="_blank">F-GSQH</a></td>
#  </tr>
#  <tr class="row-84 even">
#  <td class="column-1">22.06.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA1336 / AAL1336</td><td class="column-4">Dallas</td><td class="column-5">Orlando</td><td class="column-6">Dallas</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Airbus A321-253NX</td><td class="column-10">N429AN</td>
#  </tr>
#  <tr class="row-85 odd">
#  <td class="column-1">22.06.2022</td><td class="column-2">EasyJet</td><td class="column-3">U26892 / EZY6892</td><td class="column-4">Dalaman</td><td class="column-5">Glasgow</td><td class="column-6">Frankfurt</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Airbus A320-251N</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-uzla/" rel="noopener" target="_blank">G-UZLA</a></td>
#  </tr>
#  <tr class="row-86 even">
#  <td class="column-1">21.06.2022</td><td class="column-2">Iran Air</td><td class="column-3">IR1835 / IRA1835</td><td class="column-4">Jeddah</td><td class="column-5">Mashhad</td><td class="column-6">Bushehr</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Airbus A300B4-605R</td><td class="column-10">EP-IBA</td>
#  </tr>
#  <tr class="row-87 odd">
#  <td class="column-1">21.06.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA1984 / AAL1984</td><td class="column-4">Chicago</td><td class="column-5">Charlotte</td><td class="column-6">Indianapolis</td><td class="column-7"></td><td class="column-8">cracked windshield</td><td class="column-9">Boeing 737-823</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n819nn/" rel="noopener" target="_blank">N819NN</a></td>
#  </tr>
#  <tr class="row-88 even">
#  <td class="column-1">21.06.2022</td><td class="column-2">Austrian Airlines</td><td class="column-3">OS93 / AUA93</td><td class="column-4">Vienna</td><td class="column-5">Washington</td><td class="column-6">Shannon</td><td class="column-7"></td><td class="column-8">navigation system issue</td><td class="column-9">Boeing 767-3Z9(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/oe-lae/" rel="noopener" target="_blank">OE-LAE</a></td>
#  </tr>
#  <tr class="row-89 odd">
#  <td class="column-1">21.06.2022</td><td class="column-2">SunExpress</td><td class="column-3">XQ598 / SXS27B</td><td class="column-4">Antalya</td><td class="column-5">Edinburgh</td><td class="column-6">Frankfurt</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 737-86J</td><td class="column-10">TC-SNV</td>
#  </tr>
#  <tr class="row-90 even">
#  <td class="column-1">21.06.2022</td><td class="column-2">American Airlines</td><td class="column-3">AA209 / AAL209</td><td class="column-4">Dublin</td><td class="column-5">Chicago</td><td class="column-6">Shannon</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 787-8 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n805an/" rel="noopener" target="_blank">N805AN</a></td>
#  </tr>
#  <tr class="row-91 odd">
#  <td class="column-1">21.06.2022</td><td class="column-2">Jetstar Airways</td><td class="column-3">JQ61 / JST61</td><td class="column-4">Sydney</td><td class="column-5">Ho Chi Minh City</td><td class="column-6">Sydney</td><td class="column-7"></td><td class="column-8">mechanical/air conditioning issue</td><td class="column-9">Boeing 787-8 Dreamliner</td><td class="column-10">VH-VKG</td>
#  </tr>
#  <tr class="row-92 even">
#  <td class="column-1">20.06.2022</td><td class="column-2">British Airways</td><td class="column-3">BA783 / BAW783C</td><td class="column-4">Stockholm</td><td class="column-5">London</td><td class="column-6">Stockholm</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Airbus A321-231</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-euxi/" rel="noopener" target="_blank">G-EUXI</a></td>
#  </tr>
#  <tr class="row-93 odd">
#  <td class="column-1">20.06.2022</td><td class="column-2">SpiceJet</td><td class="column-3">SG23 / SEJ023</td><td class="column-4">Madurai</td><td class="column-5">Dubai</td><td class="column-6">Goa</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-8GJ</td><td class="column-10">VT-SZK</td>
#  </tr>
#  <tr class="row-94 even">
#  <td class="column-1">20.06.2022</td><td class="column-2">FlySafair</td><td class="column-3">FA478 / SFR</td><td class="column-4">Johannesburg</td><td class="column-5">Durban</td><td class="column-6">Johannesburg</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Boeing 737-4Y0</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/zs-jre/" rel="noopener" target="_blank">ZS-JRE</a></td>
#  </tr>
#  <tr class="row-95 odd">
#  <td class="column-1">19.06.2022</td><td class="column-2">Qatar Airways</td><td class="column-3">QR777 / QTR25Q</td><td class="column-4">Doha</td><td class="column-5">Miami</td><td class="column-6">Madrid</td><td class="column-7"></td><td class="column-8">possible technical issue</td><td class="column-9">Airbus A350-941</td><td class="column-10">A7-AML</td>
#  </tr>
#  <tr class="row-96 even">
#  <td class="column-1">19.06.2022</td><td class="column-2">IndiGo</td><td class="column-3">6E6394 / IGO6394</td><td class="column-4">Guwahati</td><td class="column-5">Delhi</td><td class="column-6">Guwahati</td><td class="column-7"></td><td class="column-8">suspected bird strike</td><td class="column-9">Airbus A320-271N</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/vt-itb/" rel="noopener" target="_blank">VT-ITB</a></td>
#  </tr>
#  <tr class="row-97 odd">
#  <td class="column-1">19.06.2022</td><td class="column-2">Enter Air</td><td class="column-3">E46051 / ENT6051</td><td class="column-4">Basel</td><td class="column-5">Pristina</td><td class="column-6">Basel</td><td class="column-7">7700</td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-8Q8</td><td class="column-10">SP-ENR</td>
#  </tr>
#  <tr class="row-98 even">
#  <td class="column-1">19.06.2022</td><td class="column-2">SpiceJet</td><td class="column-3">SG723 / SEJ723</td><td class="column-4">Patna</td><td class="column-5">Delhi</td><td class="column-6">Patna</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Boeing 737-85R</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/vt-syz/" rel="noopener" target="_blank">VT-SYZ</a></td>
#  </tr>
#  <tr class="row-99 odd">
#  <td class="column-1">19.06.2022</td><td class="column-2">SpiceJet</td><td class="column-3">SG2962 / SEJ2962</td><td class="column-4">Delhi</td><td class="column-5">Jabalpur</td><td class="column-6">Delhi</td><td class="column-7"></td><td class="column-8">pressurisation issue</td><td class="column-9">De Havilland Canada Dash 8-400</td><td class="column-10"></td>
#  </tr>
#  <tr class="row-100 even">
#  <td class="column-1">18.06.2022</td><td class="column-2">World2Fly</td><td class="column-3">3P1155 / WPT1155</td><td class="column-4">Lisbon</td><td class="column-5">Varadero</td><td class="column-6">Lisbon</td><td class="column-7"></td><td class="column-8">possible landing gear issue</td><td class="column-9">Airbus A330-343</td><td class="column-10">CS-WFP</td>
#  </tr>
#  <tr class="row-101 odd">
#  <td class="column-1">17.06.2022</td><td class="column-2">Air Canada</td><td class="column-3">AC8729 / JZA729</td><td class="column-4">Toronto</td><td class="column-5">Cleveland</td><td class="column-6">Toronto</td><td class="column-7"></td><td class="column-8">computer issue</td><td class="column-9">Mitsubishi CRJ-200ER</td><td class="column-10">C-FFJA</td>
#  </tr>
#  <tr class="row-102 even">
#  <td class="column-1">17.06.2022</td><td class="column-2">TAP Air Portugal</td><td class="column-3">TP277 / TAP277</td><td class="column-4">Lisbon</td><td class="column-5">Cancun</td><td class="column-6">Lisbon</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A330-941</td><td class="column-10">CS-TUR</td>
#  </tr>
#  <tr class="row-103 odd">
#  <td class="column-1">17.06.2022</td><td class="column-2">TUI Airways</td><td class="column-3">BY4574 / TOM2EB</td><td class="column-4">London</td><td class="column-5">Burgas</td><td class="column-6">Munich</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737 MAX 8</td><td class="column-10">G-TUMO</td>
#  </tr>
#  <tr class="row-104 even">
#  <td class="column-1">16.06.2022</td><td class="column-2">Lufthansa</td><td class="column-3">LH1372 / DLH8CU</td><td class="column-4">Frankfurt</td><td class="column-5">Wroclaw</td><td class="column-6">Warsaw</td><td class="column-7"></td><td class="column-8">spoiler issue</td><td class="column-9">Mitsubishi CRJ-900LR</td><td class="column-10">D-ACNB</td>
#  </tr>
#  <tr class="row-105 odd">
#  <td class="column-1">16.06.2022</td><td class="column-2">Allegiant Air</td><td class="column-3">G42593 / AAY2593</td><td class="column-4">Sarasota</td><td class="column-5">Akron</td><td class="column-6">Sarasota</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A320-214</td><td class="column-10">N285NV</td>
#  </tr>
#  <tr class="row-106 even">
#  <td class="column-1">16.06.2022</td><td class="column-2">TUI Airways</td><td class="column-3">BY189 / TOM189</td><td class="column-4">Punta Cana</td><td class="column-5">Manchester</td><td class="column-6">St. John's</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">G-TUIN</td>
#  </tr>
#  <tr class="row-107 odd">
#  <td class="column-1">15.06.2022</td><td class="column-2">Air Canada</td><td class="column-3">AC355 / ACA355</td><td class="column-4">Ottawa</td><td class="column-5">Calgary</td><td class="column-6">Toronto</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A220-300</td><td class="column-10">C-GVUN</td>
#  </tr>
#  <tr class="row-108 even">
#  <td class="column-1">14.06.2022</td><td class="column-2">Volotea</td><td class="column-3">V71611 / VOE6KK</td><td class="column-4">Mykonos</td><td class="column-5">Naples</td><td class="column-6">Bari</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A319-111</td><td class="column-10">EC-MUX</td>
#  </tr>
#  <tr class="row-109 odd">
#  <td class="column-1">14.06.2022</td><td class="column-2">Emirates</td><td class="column-3">EK412 / UAE3HJ</td><td class="column-4">Dubai</td><td class="column-5">Sydney</td><td class="column-6">Singapore</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Airbus A380-861</td><td class="column-10">A6-EUE</td>
#  </tr>
#  <tr class="row-110 even">
#  <td class="column-1">14.06.2022</td><td class="column-2">United Airlines</td><td class="column-3">UA33 / UAL33</td><td class="column-4">Tokyo</td><td class="column-5">Los Angeles</td><td class="column-6">Honolulu</td><td class="column-7"></td><td class="column-8">disruptive passenger</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">N36962</td>
#  </tr>
#  <tr class="row-111 odd">
#  <td class="column-1">14.06.2022</td><td class="column-2">Qatar Airways</td><td class="column-3">QR629 / QTR6J</td><td class="column-4">Lahore</td><td class="column-5">Doha</td><td class="column-6">Karachi</td><td class="column-7">7700</td><td class="column-8">technical issue</td><td class="column-9">Boeing 777-3DZ(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/a7-bea/" rel="noopener" target="_blank">A7-BEA</a></td>
#  </tr>
#  <tr class="row-112 even">
#  <td class="column-1">14.06.2022</td><td class="column-2">Air France</td><td class="column-3">AF121 / AFR121</td><td class="column-4">Chennai</td><td class="column-5">Paris</td><td class="column-6">Bucharest</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/f-hrbh/" rel="noopener" target="_blank">F-HRBH</a></td>
#  </tr>
#  <tr class="row-113 odd">
#  <td class="column-1">12.06.2022</td><td class="column-2">Hawaiian Airlines</td><td class="column-3">HA56 / HAL56</td><td class="column-4">Kahului</td><td class="column-5">Los Angeles</td><td class="column-6">Honolulu</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Airbus A330-243</td><td class="column-10"><a href='https://www.mysafersky.com/aircraft-registration/n381ha/"' target="_blank">N381HA</a></td>
#  </tr>
#  <tr class="row-114 even">
# ...
#  <tr class="row-648 even">
#  <td class="column-1">14.11.2021</td><td class="column-2">Spirit Airlines</td><td class="column-3">NK135 / NKS135</td><td class="column-4">Minneapolis</td><td class="column-5">Orlando</td><td class="column-6">Minneapolis</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-271N</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/N922NK/" rel="noopener" target="_blank">N922NK</a></td>
#  </tr>
#  <tr class="row-649 odd">
#  <td class="column-1">14.11.2021</td><td class="column-2">Ryanair</td><td class="column-3">FR1344 / RYR89VY</td><td class="column-4">Shannon</td><td class="column-5">Lanzarote</td><td class="column-6">Shannon</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 737-8AS</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/ei-efj/" rel="noopener" target="_blank">EI-EFJ</a></td>
#  </tr>
#  <tr class="row-650 even">
#  <td class="column-1">13.11.2021</td><td class="column-2">American Airlines</td><td class="column-3">AA146 / AAL146</td><td class="column-4">New York</td><td class="column-5">Tel Aviv</td><td class="column-6">Paris</td><td class="column-7">7700</td><td class="column-8"></td><td class="column-9">Boeing 777-223(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n779an/" rel="noopener" target="_blank">N779AN</a></td>
#  </tr>
#  <tr class="row-651 odd">
#  <td class="column-1">12.11.2021</td><td class="column-2">Voyageur Airways</td><td class="column-3">VC200 / VAL200</td><td class="column-4">North Bay</td><td class="column-5">Muskoka</td><td class="column-6">North Bay</td><td class="column-7"></td><td class="column-8">engine shut down</td><td class="column-9">Mitsubishi CRJ-200ER</td><td class="column-10">C-GIXT</td>
#  </tr>
#  <tr class="row-652 even">
#  <td class="column-1">12.11.2021</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL2085 / DAL2085</td><td class="column-4">Minneapolis</td><td class="column-5">Phoenix</td><td class="column-6">Minneapolis</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Airbus A321-211</td><td class="column-10">N377DN</td>
#  </tr>
#  <tr class="row-653 odd">
#  <td class="column-1">12.11.2021</td><td class="column-2">LOT</td><td class="column-3">LO3 / LOT3T</td><td class="column-4">Warsaw</td><td class="column-5">Chicago</td><td class="column-6">Goose Bay</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10">SP-LSF</td>
#  </tr>
#  <tr class="row-654 even">
#  <td class="column-1">11.11.2021</td><td class="column-2">United Airlines</td><td class="column-3">UA4488 / GJS4488</td><td class="column-4">New York</td><td class="column-5">Washington</td><td class="column-6">New York</td><td class="column-7"></td><td class="column-8">flight control issue</td><td class="column-9">Mitsubishi CRJ-550</td><td class="column-10">N535GJ</td>
#  </tr>
#  <tr class="row-655 odd">
#  <td class="column-1">11.11.2021</td><td class="column-2">Gazpromavia</td><td class="column-3">4G292 / GZP292</td><td class="column-4">Noyabrsk</td><td class="column-5">Moscow</td><td class="column-6">Nadym</td><td class="column-7"></td><td class="column-8">air conditioning issue</td><td class="column-9">Sukhoi Superjet 100-95LR</td><td class="column-10">RA-89031</td>
#  </tr>
#  <tr class="row-656 even">
#  <td class="column-1">11.11.2021</td><td class="column-2">Air India</td><td class="column-3">AI148 / AIC148</td><td class="column-4">London</td><td class="column-5">Hyderabad</td><td class="column-6">Ankara</td><td class="column-7"></td><td class="column-8">fuel leak</td><td class="column-9">Boeing 787-8 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/vt-anb/" rel="noopener" target="_blank">VT-ANB</a></td>
#  </tr>
#  <tr class="row-657 odd">
#  <td class="column-1">11.11.2021</td><td class="column-2">American Airlines</td><td class="column-3">AA4210 / ENY4210</td><td class="column-4">Alexandria</td><td class="column-5">Dallas</td><td class="column-6">Longview</td><td class="column-7">7700</td><td class="column-8">possible mechanical issue</td><td class="column-9">Embraer ERJ-145LR</td><td class="column-10">N667GB</td>
#  </tr>
#  <tr class="row-658 even">
#  <td class="column-1">10.11.2021</td><td class="column-2">Lufthansa</td><td class="column-3">LH143 / DLH6NC</td><td class="column-4">Nuremberg</td><td class="column-5">Frankfurt</td><td class="column-6">Nuremberg</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A319-114</td><td class="column-10">D-AILM</td>
#  </tr>
#  <tr class="row-659 odd">
#  <td class="column-1">10.11.2021</td><td class="column-2">Air India</td><td class="column-3">AI754 / AIC754</td><td class="column-4">Silchar</td><td class="column-5">Kolkata</td><td class="column-6">Silchar</td><td class="column-7"></td><td class="column-8">landing gear issue</td><td class="column-9">Airbus A319-112</td><td class="column-10">VT-SCB</td>
#  </tr>
#  <tr class="row-660 even">
#  <td class="column-1">10.11.2021</td><td class="column-2">LATAM Airlines</td><td class="column-3">LA3511 / TAM3511</td><td class="column-4">Florianopolis</td><td class="column-5">Sao Paulo</td><td class="column-6">Florianopolis</td><td class="column-7"></td><td class="column-8">pressurisation issue</td><td class="column-9">Airbus A321-231</td><td class="column-10">PT-MXE</td>
#  </tr>
#  <tr class="row-661 odd">
#  <td class="column-1">09.11.2021</td><td class="column-2">United Airlines</td><td class="column-3">UA4408 / GJS4408</td><td class="column-4">Washington</td><td class="column-5">New York</td><td class="column-6">Washington</td><td class="column-7"></td><td class="column-8">mechanical issue</td><td class="column-9">Mitsubishi CRJ-550</td><td class="column-10">N545GJ</td>
#  </tr>
#  <tr class="row-662 even">
#  <td class="column-1">09.11.2021</td><td class="column-2">United Airlines</td><td class="column-3">UA957 / UAL957</td><td class="column-4">Geneva</td><td class="column-5">New York</td><td class="column-6">Dublin</td><td class="column-7"></td><td class="column-8">possible fuel (system) issue</td><td class="column-9">Boeing 767-322(ER)</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n652ua/" rel="noopener" target="_blank">N652UA</a></td>
#  </tr>
#  <tr class="row-663 odd">
#  <td class="column-1">09.11.2021</td><td class="column-2">Air India</td><td class="column-3">AI127 / AIC127</td><td class="column-4">Delhi</td><td class="column-5">Chicago</td><td class="column-6">Stockholm</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Boeing 777-337(ER)</td><td class="column-10">VT-ALQ</td>
#  </tr>
#  <tr class="row-664 even">
#  <td class="column-1">08.11.2021</td><td class="column-2">Air Canada</td><td class="column-3">AC720 / ACA720</td><td class="column-4">Toronto</td><td class="column-5">New York - LaGuardia</td><td class="column-6">New York  Newark</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A220-300</td><td class="column-10">C-GNBE</td>
#  </tr>
#  <tr class="row-665 odd">
#  <td class="column-1">08.11.2021</td><td class="column-2">Air France</td><td class="column-3">AF610K / AFR610K</td><td class="column-4">Paris</td><td class="column-5">Nantes</td><td class="column-6">Paris</td><td class="column-7">7700</td><td class="column-8">pressurisation issue</td><td class="column-9">Airbus A220-300</td><td class="column-10">F-HZUC</td>
#  </tr>
#  <tr class="row-666 even">
#  <td class="column-1">08.11.2021</td><td class="column-2">Allegiant Air</td><td class="column-3">G42471 / AAY2471</td><td class="column-4">Orlando</td><td class="column-5">Plattsburgh</td><td class="column-6">Orlando</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A320-214</td><td class="column-10">N217NV</td>
#  </tr>
#  <tr class="row-667 odd">
#  <td class="column-1">08.11.2021</td><td class="column-2">Vueling</td><td class="column-3">VY6246 / VLG6246</td><td class="column-4">Barcelona</td><td class="column-5">Zurich</td><td class="column-6">Barcelona</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Airbus A320-232</td><td class="column-10">EC-MGE</td>
#  </tr>
#  <tr class="row-668 even">
#  <td class="column-1">07.11.2021</td><td class="column-2">Vueling</td><td class="column-3">VY7108 / VLG99CH</td><td class="column-4">Santiago</td><td class="column-5">London</td><td class="column-6">Santiago</td><td class="column-7"></td><td class="column-8">engine issue</td><td class="column-9">Airbus A320-232</td><td class="column-10">EC-LVT</td>
#  </tr>
#  <tr class="row-669 odd">
#  <td class="column-1">07.11.2021</td><td class="column-2">Amelia International</td><td class="column-3">AF7604 / AFR19RA</td><td class="column-4">Paris</td><td class="column-5">Aurillac</td><td class="column-6">Toulouse</td><td class="column-7"></td><td class="column-8">possible landing gear issue</td><td class="column-9">ATR 42-500</td><td class="column-10">F-HLIA</td>
#  </tr>
#  <tr class="row-670 even">
#  <td class="column-1">07.11.2021</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL3622 / SKW3622</td><td class="column-4">Seattle</td><td class="column-5">Portland</td><td class="column-6">Seattle</td><td class="column-7"></td><td class="column-8">bird strike</td><td class="column-9">Embraer E175LR</td><td class="column-10">N262SY</td>
#  </tr>
#  <tr class="row-671 odd">
#  <td class="column-1">07.11.2021</td><td class="column-2">Swiss</td><td class="column-3">LX339 / SWR339</td><td class="column-4">London</td><td class="column-5">Zurich</td><td class="column-6">London</td><td class="column-7"></td><td class="column-8">smell in cockpit</td><td class="column-9">Airbus A220-100</td><td class="column-10">HB-JBD</td>
#  </tr>
#  <tr class="row-672 even">
#  <td class="column-1">07.11.2021</td><td class="column-2">Azul Linhas Aéreas</td><td class="column-3">AD2420 / AZU2420</td><td class="column-4">Campinas</td><td class="column-5">Jericoacoara</td><td class="column-6">Campinas</td><td class="column-7"></td><td class="column-8">pressurisation issue</td><td class="column-9">Airbus A320-251N</td><td class="column-10">PR-YYI</td>
#  </tr>
#  <tr class="row-673 odd">
#  <td class="column-1">06.11.2021</td><td class="column-2">Eurowings</td><td class="column-3">EW5110 / EWG5BG</td><td class="column-4">Cologne</td><td class="column-5">Hurghada</td><td class="column-6">Klagenfurt</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Airbus A320-214</td><td class="column-10">D-AEWK</td>
#  </tr>
#  <tr class="row-674 even">
#  <td class="column-1">06.11.2021</td><td class="column-2">Air Baltic</td><td class="column-3">BT879 / BTI8ZF</td><td class="column-4">Tallinn</td><td class="column-5">Malaga</td><td class="column-6">Tallinn</td><td class="column-7"></td><td class="column-8">lightning strike</td><td class="column-9">Airbus A220-300</td><td class="column-10">YL-CSE</td>
#  </tr>
#  <tr class="row-675 odd">
#  <td class="column-1">06.11.2021</td><td class="column-2">TUI Airways</td><td class="column-3">BY2662 / TOM37M</td><td class="column-4">Manchester</td><td class="column-5">Fuerteventura</td><td class="column-6">Manchester</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737-8K5</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/g-fdzs/" rel="noopener" target="_blank">G-FDZS</a></td>
#  </tr>
#  <tr class="row-676 even">
#  <td class="column-1">05.11.2021</td><td class="column-2">S7 Airlines</td><td class="column-3">S72103 / SBI2103</td><td class="column-4">Moscow</td><td class="column-5">Anapa</td><td class="column-6">Rostov-on-Don</td><td class="column-7"></td><td class="column-8">medical emergency</td><td class="column-9">Airbus A320-214</td><td class="column-10">VQ-BRC</td>
#  </tr>
#  <tr class="row-677 odd">
#  <td class="column-1">05.11.2021</td><td class="column-2">Air Arabia Maroc</td><td class="column-3">3O437 / MAC437</td><td class="column-4">Casablanca</td><td class="column-5">Istanbul</td><td class="column-6">Palma de Mallorca</td><td class="column-7"></td><td class="column-8">alleged medical emergency</td><td class="column-9">Airbus A320-214</td><td class="column-10">CN-NMG</td>
#  </tr>
#  <tr class="row-678 even">
#  <td class="column-1">05.11.2021</td><td class="column-2">TUI fly Netherlands</td><td class="column-3">OR611 / TFL611</td><td class="column-4">Groningen</td><td class="column-5">Gran Canaria</td><td class="column-6">Faro</td><td class="column-7"></td><td class="column-8"></td><td class="column-9">Boeing 737 MAX 8</td><td class="column-10">PH-TFP</td>
#  </tr>
#  <tr class="row-679 odd">
#  <td class="column-1">05.11.2021</td><td class="column-2">Vistara</td><td class="column-3">UK992 / VTI992</td><td class="column-4">Pune</td><td class="column-5">Delhi</td><td class="column-6">Mumbai</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Airbus A320-232</td><td class="column-10">VT-TTM</td>
#  </tr>
#  <tr class="row-680 even">
#  <td class="column-1">04.11.2021</td><td class="column-2">Allegiant Air</td><td class="column-3">G42254 / AAY2254</td><td class="column-4">Orlando</td><td class="column-5">Traverse City</td><td class="column-6">Orlando</td><td class="column-7"></td><td class="column-8">possible engine issue</td><td class="column-9">Airbus A319-112</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n307nv/" rel="noopener" target="_blank">N307NV</a></td>
#  </tr>
#  <tr class="row-681 odd">
#  <td class="column-1">04.11.2021</td><td class="column-2">Azul Linhas Aéreas</td><td class="column-3">AD4327 / AZU4327</td><td class="column-4">Goiani</td><td class="column-5">Campinas</td><td class="column-6">Brasilia</td><td class="column-7"></td><td class="column-8">technical issue</td><td class="column-9">Embraer E195-E2</td><td class="column-10">PS-AEF</td>
#  </tr>
#  <tr class="row-682 even">
#  <td class="column-1">02.11.2021</td><td class="column-2">United Airlines</td><td class="column-3">UA818 / UAL818</td><td class="column-4">Buenos Aires</td><td class="column-5">Houston</td><td class="column-6">Buenos Aires</td><td class="column-7"></td><td class="column-8">pressurisation issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/n36962/" rel="noopener" target="_blank">N36962</a></td>
#  </tr>
#  <tr class="row-683 odd">
#  <td class="column-1">01.11.2021</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL9962 / DAL9962</td><td class="column-4">Atlanta</td><td class="column-5">Key West</td><td class="column-6">Atlanta</td><td class="column-7"></td><td class="column-8">airspeed issue</td><td class="column-9">Airbus A319-114</td><td class="column-10">N364NB</td>
#  </tr>
#  <tr class="row-684 even">
#  <td class="column-1">01.11.2021</td><td class="column-2">Delta Air Lines</td><td class="column-3">DL365 / DAL365</td><td class="column-4">Atlanta</td><td class="column-5">Los Angeles</td><td class="column-6">Dallas</td><td class="column-7"></td><td class="column-8">disruptive passenger</td><td class="column-9">Airbus A321-211</td><td class="column-10">N390DN</td>
#  </tr>
#  <tr class="row-685 odd">
#  <td class="column-1">01.11.2021</td><td class="column-2">El Al</td><td class="column-3">LY82 / ELY082</td><td class="column-4">Bangkok</td><td class="column-5">Tel Aviv</td><td class="column-6">Goa</td><td class="column-7"></td><td class="column-8">possible fuel (system) issue</td><td class="column-9">Boeing 787-9 Dreamliner</td><td class="column-10"><a href="https://www.mysafersky.com/aircraft-registration/4x-eda/" rel="noopener" target="_blank">4X-EDA</a></td>
#  </tr>
#  </tbody>
#  </table>]

# %%
#Load the data table to a dataframe
flight_diverted_table = pd.read_html(str(flight_diverted_table))
flight_diverted_df = flight_diverted_table[0]
flight_diverted_df
# Out:
#            Date   Airlines/Operator     Flight number Departure airport  \
# 0    20.07.2022            Go First    G8151 / GOW151             Delhi
# 1    20.07.2022            Wizz Air  W65058 / WZZ101S              Bari
# 2    19.07.2022            Go First    G8386 / GOW386            Mumbai
# 3    19.07.2022            Go First  G86202 / GOW6202          Srinagar
# 4    19.07.2022                 LOT  LO6297 / LOT6297            Prague
# ..          ...                 ...               ...               ...
# 679  04.11.2021  Azul Linhas Aéreas  AD4327 / AZU4327            Goiani
# 680  02.11.2021     United Airlines    UA818 / UAL818      Buenos Aires
# 681  01.11.2021     Delta Air Lines  DL9962 / DAL9962           Atlanta
# 682  01.11.2021     Delta Air Lines    DL365 / DAL365           Atlanta
# 683  01.11.2021               El Al     LY82 / ELY082           Bangkok
#
#     Destination airport   Diverted to  Emergency code  \
# 0              Guwahati        Jaipur             NaN
# 1                Krakow      Budapest             NaN
# 2                   Leh         Delhi             NaN
# 3                 Delhi      Srinagar             NaN
# 4              Zanzibar        Warsaw             NaN
# ..                  ...           ...             ...
# 679            Campinas      Brasilia             NaN
# 680             Houston  Buenos Aires             NaN
# 681            Key West       Atlanta             NaN
# 682         Los Angeles        Dallas             NaN
# 683            Tel Aviv           Goa             NaN
#
#                    Alleged reason                 Aircraft Registration
# 0              cracked windshield         Airbus A320-271N       VT-WGP
# 1                     bomb threat        Airbus A321-271NX       HA-LGA
# 2                    engine issue         Airbus A320-271N       VT-WGA
# 3                    engine issue         Airbus A320-271N       VT-WJG
# 4                    brakes issue  Boeing 787-9 Dreamliner       SP-LSB
# ..                            ...                      ...          ...
# 679               technical issue          Embraer E195-E2       PS-AEF
# 680          pressurisation issue  Boeing 787-9 Dreamliner       N36962
# 681                airspeed issue          Airbus A319-114       N364NB
# 682          disruptive passenger          Airbus A321-211       N390DN
# 683  possible fuel (system) issue  Boeing 787-9 Dreamliner       4X-EDA
#
# [684 rows x 10 columns]

# %% [raw]
# # Another way of reading html data without having to parse it
# #Read Diverted data from "https://www.diverted.eu/" into a dataframe
# url = 'https://www.diverted.eu/'
# df =  pd.read_html(url)
# data = df[0]

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### String to Date conversion

# %%
flight_diverted_df.Date.dtype
# Out:
# dtype('O')

# %% [markdown]
# >Flight date is formatted as a string (Pandas type 'O' is a string).

# %%
#Format Flight date from string to Date 
flight_diverted_df.Date = pd.to_datetime(flight_diverted_df["Date"], format='%d.%m.%Y') 
flight_diverted_df.head(5)
# Out:
#         Date Airlines/Operator     Flight number Departure airport  \
# 0 2022-07-20          Go First    G8151 / GOW151             Delhi
# 1 2022-07-20          Wizz Air  W65058 / WZZ101S              Bari
# 2 2022-07-19          Go First    G8386 / GOW386            Mumbai
# 3 2022-07-19          Go First  G86202 / GOW6202          Srinagar
# 4 2022-07-19               LOT  LO6297 / LOT6297            Prague
#
#   Destination airport Diverted to  Emergency code      Alleged reason  \
# 0            Guwahati      Jaipur             NaN  cracked windshield
# 1              Krakow    Budapest             NaN         bomb threat
# 2                 Leh       Delhi             NaN        engine issue
# 3               Delhi    Srinagar             NaN        engine issue
# 4            Zanzibar      Warsaw             NaN        brakes issue
#
#                   Aircraft Registration
# 0         Airbus A320-271N       VT-WGP
# 1        Airbus A321-271NX       HA-LGA
# 2         Airbus A320-271N       VT-WGA
# 3         Airbus A320-271N       VT-WJG
# 4  Boeing 787-9 Dreamliner       SP-LSB

# %% [markdown]
# #### Filter Flights by Date

# %% [markdown]
# >Only select data for May'22, since our excel data is for May 2022

# %%
diverted_df = flight_diverted_df[(flight_diverted_df.Date >= '2022-05-01') & (flight_diverted_df.Date < '2022-06-01')]
diverted_df.head(5)
# Out:
#           Date  Airlines/Operator     Flight number Departure airport  \
# 147 2022-05-31   Virgin Australia  VA9223 / VOZ9223             Perth
# 148 2022-05-31         Aer Lingus  EI3326 / EAI26MH            Dublin
# 149 2022-05-30  American Airlines    AA720 / AAL720         Charlotte
# 150 2022-05-29              Swiss   LX340 / SWR340V            Zurich
# 151 2022-05-29             Qantas    QF2008 / QLK8D            Sydney
#
#     Destination airport Diverted to  Emergency code     Alleged reason  \
# 147           Boolgeeda       Perth             NaN    hydraulic issue
# 148          Manchester      Dublin          7700.0    technical issue
# 149                Rome   Charlotte             NaN  maintenance issue
# 150              London      Zurich             NaN    odor in cockpit
# 151            Tamworth      Sydney             NaN    hydraulic issue
#
#                            Aircraft Registration
# 147                 Airbus A320-232       VH-VNB
# 148                      ATR 72-600       EI-HDH
# 149              Boeing 777-223(ER)       N793AN
# 150                 Airbus A220-100       HB-JBI
# 151  De Havilland Canada Dash 8-400       VH-QOF

# %% [markdown]
# #### Repalce Headers

# %%
#Columns before renaming
diverted_df.columns
# Out:
# Index(['Date', 'Airlines/Operator', 'Flight number', 'Departure airport',
#        'Destination airport', 'Diverted to', 'Emergency code',
#        'Alleged reason', 'Aircraft', 'Registration'],
#       dtype='object')

# %%
#Renaming columns
diverted_df.columns = ['FL_DATE', 'OP_UNIQUE_CARRIER', 'FL_NUM', 'ORIGIN', 'DEST', 'DIVERTED_TO', 'EMERGENCY_CODE', 'DIVERTED_REASON', 'AIRCRAFT', 'AIRCRAFT_REGISTRATION']

# %%
#Columns after renaming
diverted_df.columns
# Out:
# Index(['FL_DATE', 'OP_UNIQUE_CARRIER', 'FL_NUM', 'ORIGIN', 'DEST',
#        'DIVERTED_TO', 'EMERGENCY_CODE', 'DIVERTED_REASON', 'AIRCRAFT',
#        'AIRCRAFT_REGISTRATION'],
#       dtype='object')

# %% [markdown]
# #### Drop rows

# %% [markdown]
# ###### Drop null rows, if any

# %%
print('Data before dropping null rows : ',diverted_df.shape)
diverted_df.dropna()
print('Data after dropping null rows : ', diverted_df.shape)
# Out:
# Data before dropping null rows :  (87, 10)
# Data after dropping null rows :  (87, 10)

# %% [markdown]
# >No null rows to drop

# %% [markdown]
# ###### Drop duplicates, if any

# %%
print('Dataframe before dropping duplicates :', diverted_df.shape)
diverted_df = diverted_df.drop_duplicates() 
print('Dataframe after dropping duplicates :',diverted_df.shape)
#No duplicates in the website data table
# Out:
# Dataframe before dropping duplicates : (87, 10)
# Dataframe after dropping duplicates : (87, 10)

# %% [markdown]
# #### Update rows
#
# >Look for rows with inconsistent reason for diversion

# %%
diverted_df.groupby(['DIVERTED_REASON'])['DIVERTED_REASON'].count()
# Out:
# DIVERTED_REASON
# air conditioning issue          1
# bird strike                     8
# bomb threat                     1
# brakes issue                    1
# cracked windshield              1
# disruptive passenger            5
# engine issue                    4
# hydraulic issue                 5
# landing gear issue              3
# maintenance issue               1
# medical emergency              14
# odor in cockpit                 1
# odor on board                   2
# operational reasons             1
# possible landing gear issue     1
# possible medical emergency      1
# possible technical issue        2
# pressurisation issue            6
# smell on board                  3
# smoke indication                1
# smoke on board                  1
# technical issue                 8
# weather radar issue             1
# winglet issue                   1
# “rostering error”               1
# Name: DIVERTED_REASON, dtype: int64

# %% [markdown]
# >Rostering error has unwanted quotes. Removing them for consistency.

# %%
diverted_df.loc[diverted_df.DIVERTED_REASON == '“rostering error”', 'DIVERTED_REASON'] = 'rostering_error'

# %%
#Validate data after update
diverted_df.groupby(['DIVERTED_REASON'])['DIVERTED_REASON'].count()
# Out:
# DIVERTED_REASON
# air conditioning issue          1
# bird strike                     8
# bomb threat                     1
# brakes issue                    1
# cracked windshield              1
# disruptive passenger            5
# engine issue                    4
# hydraulic issue                 5
# landing gear issue              3
# maintenance issue               1
# medical emergency              14
# odor in cockpit                 1
# odor on board                   2
# operational reasons             1
# possible landing gear issue     1
# possible medical emergency      1
# possible technical issue        2
# pressurisation issue            6
# rostering_error                 1
# smell on board                  3
# smoke indication                1
# smoke on board                  1
# technical issue                 8
# weather radar issue             1
# winglet issue                   1
# Name: DIVERTED_REASON, dtype: int64

# %% [markdown]
# #### Fill NA/NaN values

# %%
print('EMERGENCY_CODE before updating NA/NAN : ',diverted_df.EMERGENCY_CODE.unique())
# Out:
# EMERGENCY_CODE before updating NA/NAN :  [  nan 7700.]

# %%
diverted_df = diverted_df.replace(np.nan,0)

# %%
print('EMERGENCY_CODE after updating NA/NAN : ',diverted_df.EMERGENCY_CODE.unique())
# Out:
# EMERGENCY_CODE after updating NA/NAN :  [   0. 7700.]

# %% [markdown]
# ### Ethical implications:
# >Website Data -
# The data source of the flat file is genuine and reliable (Bureau of Transportation). However, the website may not hold accurate information because it is not government or FAA authorized source. The webiste does not mention the source of data, making the accuracy and legality of data questionable. The website also states the same in the disclaimer. However, on running a high level search for a couple of diverted flight information, we are able to confirm the accuracy of the data.

# %% [markdown]
# ### Conclusion:
# >As a part of this milestone, the following Data Transformation steps have been performed.
#
# >1. Data Type conversion
# >2. Renamed columns
# >3. Replaced values in a dataframe column
# >4. Filtered data
# >5. Filled NA/NAN values
# >6. Performed checks for duplicates and null rows

# %% [markdown]
# ## Milestone 4 - Connecting to an API/Pulling in the Data and Cleaning/Formatting

# %% [markdown]
# >Data from the flat file has cancellations and delays due to weather.
# The API gets the historic weather data for a location (origin or destination city name). This will enable us to validate if there truly was a bad weather situation for a flight to be delayed or cancelled. With this, we can also identify the cause of bad weather like storms, snow, wind, etc.

# %%
#Working with weather delays. Creating a dataframe with only weather delays. 
weather_delay_df = flight_data_df[flight_data_df.DELAY_REASON=='Weather']
print(weather_delay_df.shape)
weather_delay_df.head(5)
# Out:
# (4152, 35)
#       YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 87    2022        2      5             1            7  5/1/2022 12:00:00 AM
# 191   2022        2      5             1            7  5/1/2022 12:00:00 AM
# 227   2022        2      5             1            7  5/1/2022 12:00:00 AM
# 1962  2022        2      5             1            7  5/1/2022 12:00:00 AM
# 2000  2022        2      5             1            7  5/1/2022 12:00:00 AM
#
#      MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN    ORIGIN_CITY_NAME  ...  \
# 87                   AA                AA    BHM      Birmingham, AL  ...
# 191                  AA                AA    CLE       Cleveland, OH  ...
# 227                  AA                AA    CLT       Charlotte, NC  ...
# 1962                 AA                AA    PIT      Pittsburgh, PA  ...
# 2000                 AA                AA    RDU  Raleigh/Durham, NC  ...
#
#      DIVERTED DISTANCE CARRIER_DELAY WEATHER_DELAY NAS_DELAY SECURITY_DELAY  \
# 87        0.0    597.0           0.0          61.0       0.0            0.0
# 191       0.0   1737.0           0.0          18.0       0.0            0.0
# 227       0.0    361.0           0.0          19.0       6.0            0.0
# 1962      0.0   1814.0           0.0          18.0       0.0            0.0
# 2000      0.0    587.0           0.0          47.0      12.0            0.0
#
#       LATE_AIRCRAFT_DELAY   STATUS  DELAYED  DELAY_REASON
# 87                    0.0  Delayed     True       Weather
# 191                   0.0  Delayed     True       Weather
# 227                   0.0  Delayed     True       Weather
# 1962                  0.0  Delayed     True       Weather
# 2000                  0.0  Delayed     True       Weather
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Function to make the API call to get historic weather data based on flight time and origin.

# %%
def get_historic_geo_data_by_zip(startDateTime, originCityName, endDateTime):
    #URL
    #url = 'https://visual-crossing-weather.p.rapidapi.com/history?'
    #API key Request Headers
    headers = {"X-RapidAPI-Key": "046c439acamshd081e11265aa749p15f219jsn1275dc460233",
               "X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com"}
    #URL
    geocode_request_url = "https://visual-crossing-weather.p.rapidapi.com/history?" 
    #Request Parameters
    parms = {'startDateTime': startDateTime, 'aggregateHours': 24, 'location': originCityName,
             'endDateTime': endDateTime, 'unitGroup': 'us'}
    try:
        #API call to get the weather data at the scheduled time of flight.
        response = requests.get(geocode_request_url, params=parms, headers=headers)
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        print('There was an error in the API call : ', e)
    except requests.exceptions.Timeout as t:
        print('The API call timedout. Please retry.')
    return response

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### 1. Data manipulation using regular expressions to convert response text into a list of keys and values
#
# #### 2. Data transformation to parse the list of keys and values to form a dictionary (key-value pair)

# %%
#Function to process the API response
def process_api_data(response, index):
    try:
        if response.status_code==200: #OK
            try:
                 # The API response is not a formatted JSON. Parsing through the text to create a key-value pair
                json_data = response.text.splitlines()
                if len(json_data) <= 2: #We only expect a list of keys and values. Ideally there shouldn't be a count > 2
                    keys = (re.split(',', json_data[0])) 
                    # replace ', ' by | to be able to split the strings correctly for key value pair
                    values = (json_data[1].replace(', ','|').replace('"', '')).split(',') 
                    #print(len(keys), len(values))
                    if len(keys) == len(values): #Converting to dict only when keys and values count match.
                        for i in range(len(keys)): 
                            historic_weather_data[keys[i]] = values[i]  
                    else:
                        print("Key value pair counts don't match")
            except RuntimeError as ex:
                print('There was an error in processing the API response : ', ex)
        elif response.status_code==404:
            print("Requested historic weather data not found for parms : Fl_Date - ",start_date_time, ' City - ',row.ORIGIN_CITY_NAME)
        else:
            print('Unable to get historic weather data for parms : Fl_Date - ',start_date_time, ' City - ',row.ORIGIN_CITY_NAME)
    except RuntimeError as ex:
        print("There was an error in dictionary creation from API response.")
    
    return historic_weather_data

# %% [markdown]
# #### Function call to create the API request, get and process the response.

# %% [markdown]
# #### 3. Data transformation to convert the dictionary to a dataframe

# %%
index = 0 
historic_weather_data = {}
weather_data_df = pd.DataFrame()

for inx, row in weather_delay_df.iterrows():
    start_date_time = pd.to_datetime(row.FL_DATE).strftime("%Y-%m-%dT%H:%M:%S") #Fl start time
    end_date_time=start_date_time 

    #Switching back the if condition and reducing the API calls to 2, incase of a rerun to avoid reaching the API limit. 
    #Since this is a public API there is a limit to the number of calls I can make per month.
    #The loop for entire dataframe has been run and the weather_data_df is created for all rows in weather_delay_df.
    #This condition will be removed again for the final project submission 
    if index < 2: 
        #Call funtion to get weather at origin and flight time
        response = get_historic_geo_data_by_zip(start_date_time,row.ORIGIN_CITY_NAME , end_date_time) 

        weather_dict={}
        weather_dict = process_api_data(response, index) #Get each API response in a dict

        df  = pd.DataFrame([weather_dict], columns=weather_dict.keys()) #Convert dict to a dataframe
        weather_data_df = pd.concat([weather_data_df, df], axis =0).reset_index(drop=True) #Append dict to dataframe rows

        index = index + 1
# Out:
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25
# 25 25

# %%
# Final weather_data_df
weather_data_df
# Out:
#                 Address   Date time Minimum Temperature Maximum Temperature  \
# 0         Birmingham|AL  05/01/2022                65.0                82.1
# 1          Cleveland|OH  05/01/2022                53.1                74.0
# 2          Charlotte|NC  05/01/2022                57.3                80.5
# 3         Pittsburgh|PA  05/01/2022                53.5                70.4
# 4     Raleigh/Durham|NC  05/01/2022                50.5                82.2
# ...                 ...         ...                 ...                 ...
# 4147        Savannah|GA  05/31/2022                70.5                84.0
# 4148          Dallas|TX  05/31/2022                76.0                92.3
# 4149     Kansas City|MO  05/31/2022                65.0                78.2
# 4150           Tampa|FL  05/31/2022                72.7                91.2
# 4151           Tampa|FL  05/31/2022                72.7                91.2
#
#      Temperature Dew Point Relative Humidity Heat Index Wind Speed Wind Gust  \
# 0           73.0      63.6             73.68       83.5       10.8      36.7
# 1           62.2      45.6              60.2                  18.3      30.2
# 2           68.6      59.5             73.82       81.8       13.1      20.7
# 3           60.8      46.6             64.71                   9.2      23.5
# 4           65.0      57.3              79.5       82.6       12.5      20.8
# ...          ...       ...               ...        ...        ...       ...
# 4147        76.6      73.2             89.54       91.7        8.8
# 4148        84.0      69.4             63.24       96.7       18.3      31.6
# 4149        72.3      65.9              81.0                  16.1      42.5
# 4150        80.3      69.3             71.22       95.5       15.3      24.2
# 4151        80.3      69.3             71.22       95.5       15.3      24.2
#
#       ... Visibility Cloud Cover Sea Level Pressure  \
# 0     ...        9.4        66.8             1016.0
# 1     ...        9.4        75.6             1010.3
# 2     ...        9.9        64.2             1017.5
# 3     ...        8.8        76.1             1013.4
# 4     ...        8.2        66.1             1018.2
# ...   ...        ...         ...                ...
# 4147  ...        9.8        34.3             1018.7
# 4148  ...        9.9        59.3             1009.8
# 4149  ...        8.4        87.7             1009.7
# 4150  ...        9.9        43.1             1016.4
# 4151  ...        9.9        43.1             1016.4
#
#                                            Weather Type Latitude Longitude  \
# 0     Lightning Without Thunder|Mist|Thunderstorm|Ra...  33.5207  -86.8118
# 1                          Mist|Thunderstorm|Light Rain  41.5047  -81.6908
# 2                             Lightning Without Thunder  35.2229   -80.838
# 3     Lightning Without Thunder|Mist|Thunderstorm|Ra...  40.4385  -79.9973
# 4     Mist|Light Drizzle|Thunderstorm|Rain|Fog|Heavy...  35.9869  -78.6686
# ...                                                 ...      ...       ...
# 4147  Lightning Without Thunder|Mist|Rain|Thundersto...  32.0809  -81.0912
# 4148                                                     32.7782  -96.7951
# 4149  Lightning Without Thunder|Mist|Thunderstorm|Ra...  39.1034  -94.5831
# 4150  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
# 4151  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
#
#                               Resolved Address  \
# 0                  Birmingham|AL|United States
# 1                   Cleveland|OH|United States
# 2                   Charlotte|NC|United States
# 3                  Pittsburgh|PA|United States
# 4     Durham Rd|Raleigh|NC 27614|United States
# ...                                        ...
# 4147                 Savannah|GA|United States
# 4148                   Dallas|TX|United States
# 4149              Kansas City|MO|United States
# 4150                    Tampa|FL|United States
# 4151                    Tampa|FL|United States
#
#                                           Name Info             Conditions
# 0                  Birmingham|AL|United States       Rain|Partially cloudy
# 1                   Cleveland|OH|United States               Rain|Overcast
# 2                   Charlotte|NC|United States       Rain|Partially cloudy
# 3                  Pittsburgh|PA|United States               Rain|Overcast
# 4     Durham Rd|Raleigh|NC 27614|United States       Rain|Partially cloudy
# ...                                        ...  ...                    ...
# 4147                 Savannah|GA|United States       Rain|Partially cloudy
# 4148                   Dallas|TX|United States            Partially cloudy
# 4149              Kansas City|MO|United States               Rain|Overcast
# 4150                    Tampa|FL|United States       Rain|Partially cloudy
# 4151                    Tampa|FL|United States       Rain|Partially cloudy
#
# [4152 rows x 25 columns]

# %% [markdown]
# >Now that we have the weather data in dataframe, we'll perform the Data Transformation Steps

# %% [markdown]
# #### 4. Look for empty rows and null values

# %%
weather_data_df.dropna()
# Out:
#                 Address   Date time Minimum Temperature Maximum Temperature  \
# 0         Birmingham|AL  05/01/2022                65.0                82.1
# 1          Cleveland|OH  05/01/2022                53.1                74.0
# 2          Charlotte|NC  05/01/2022                57.3                80.5
# 3         Pittsburgh|PA  05/01/2022                53.5                70.4
# 4     Raleigh/Durham|NC  05/01/2022                50.5                82.2
# ...                 ...         ...                 ...                 ...
# 4147        Savannah|GA  05/31/2022                70.5                84.0
# 4148          Dallas|TX  05/31/2022                76.0                92.3
# 4149     Kansas City|MO  05/31/2022                65.0                78.2
# 4150           Tampa|FL  05/31/2022                72.7                91.2
# 4151           Tampa|FL  05/31/2022                72.7                91.2
#
#      Temperature Dew Point Relative Humidity Heat Index Wind Speed Wind Gust  \
# 0           73.0      63.6             73.68       83.5       10.8      36.7
# 1           62.2      45.6              60.2                  18.3      30.2
# 2           68.6      59.5             73.82       81.8       13.1      20.7
# 3           60.8      46.6             64.71                   9.2      23.5
# 4           65.0      57.3              79.5       82.6       12.5      20.8
# ...          ...       ...               ...        ...        ...       ...
# 4147        76.6      73.2             89.54       91.7        8.8
# 4148        84.0      69.4             63.24       96.7       18.3      31.6
# 4149        72.3      65.9              81.0                  16.1      42.5
# 4150        80.3      69.3             71.22       95.5       15.3      24.2
# 4151        80.3      69.3             71.22       95.5       15.3      24.2
#
#       ... Visibility Cloud Cover Sea Level Pressure  \
# 0     ...        9.4        66.8             1016.0
# 1     ...        9.4        75.6             1010.3
# 2     ...        9.9        64.2             1017.5
# 3     ...        8.8        76.1             1013.4
# 4     ...        8.2        66.1             1018.2
# ...   ...        ...         ...                ...
# 4147  ...        9.8        34.3             1018.7
# 4148  ...        9.9        59.3             1009.8
# 4149  ...        8.4        87.7             1009.7
# 4150  ...        9.9        43.1             1016.4
# 4151  ...        9.9        43.1             1016.4
#
#                                            Weather Type Latitude Longitude  \
# 0     Lightning Without Thunder|Mist|Thunderstorm|Ra...  33.5207  -86.8118
# 1                          Mist|Thunderstorm|Light Rain  41.5047  -81.6908
# 2                             Lightning Without Thunder  35.2229   -80.838
# 3     Lightning Without Thunder|Mist|Thunderstorm|Ra...  40.4385  -79.9973
# 4     Mist|Light Drizzle|Thunderstorm|Rain|Fog|Heavy...  35.9869  -78.6686
# ...                                                 ...      ...       ...
# 4147  Lightning Without Thunder|Mist|Rain|Thundersto...  32.0809  -81.0912
# 4148                                                     32.7782  -96.7951
# 4149  Lightning Without Thunder|Mist|Thunderstorm|Ra...  39.1034  -94.5831
# 4150  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
# 4151  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
#
#                               Resolved Address  \
# 0                  Birmingham|AL|United States
# 1                   Cleveland|OH|United States
# 2                   Charlotte|NC|United States
# 3                  Pittsburgh|PA|United States
# 4     Durham Rd|Raleigh|NC 27614|United States
# ...                                        ...
# 4147                 Savannah|GA|United States
# 4148                   Dallas|TX|United States
# 4149              Kansas City|MO|United States
# 4150                    Tampa|FL|United States
# 4151                    Tampa|FL|United States
#
#                                           Name Info             Conditions
# 0                  Birmingham|AL|United States       Rain|Partially cloudy
# 1                   Cleveland|OH|United States               Rain|Overcast
# 2                   Charlotte|NC|United States       Rain|Partially cloudy
# 3                  Pittsburgh|PA|United States               Rain|Overcast
# 4     Durham Rd|Raleigh|NC 27614|United States       Rain|Partially cloudy
# ...                                        ...  ...                    ...
# 4147                 Savannah|GA|United States       Rain|Partially cloudy
# 4148                   Dallas|TX|United States            Partially cloudy
# 4149              Kansas City|MO|United States               Rain|Overcast
# 4150                    Tampa|FL|United States       Rain|Partially cloudy
# 4151                    Tampa|FL|United States       Rain|Partially cloudy
#
# [4152 rows x 25 columns]

# %% [markdown]
# >No null rows to drop.

# %% [markdown]
# #### 5. Drop Columns

# %%
weather_data_df.groupby(['Info'])['Info'].count().sort_index()
#There doesn't seem to be any relevant information in the Info column.

# %%
 weather_data_df[weather_data_df['Resolved Address'] == weather_data_df['Name']]
# Out:
#                 Address   Date time Minimum Temperature Maximum Temperature  \
# 0         Birmingham|AL  05/01/2022                65.0                82.1
# 1          Cleveland|OH  05/01/2022                53.1                74.0
# 2          Charlotte|NC  05/01/2022                57.3                80.5
# 3         Pittsburgh|PA  05/01/2022                53.5                70.4
# 4     Raleigh/Durham|NC  05/01/2022                50.5                82.2
# ...                 ...         ...                 ...                 ...
# 4147        Savannah|GA  05/31/2022                70.5                84.0
# 4148          Dallas|TX  05/31/2022                76.0                92.3
# 4149     Kansas City|MO  05/31/2022                65.0                78.2
# 4150           Tampa|FL  05/31/2022                72.7                91.2
# 4151           Tampa|FL  05/31/2022                72.7                91.2
#
#      Temperature Dew Point Relative Humidity Heat Index Wind Speed Wind Gust  \
# 0           73.0      63.6             73.68       83.5       10.8      36.7
# 1           62.2      45.6              60.2                  18.3      30.2
# 2           68.6      59.5             73.82       81.8       13.1      20.7
# 3           60.8      46.6             64.71                   9.2      23.5
# 4           65.0      57.3              79.5       82.6       12.5      20.8
# ...          ...       ...               ...        ...        ...       ...
# 4147        76.6      73.2             89.54       91.7        8.8
# 4148        84.0      69.4             63.24       96.7       18.3      31.6
# 4149        72.3      65.9              81.0                  16.1      42.5
# 4150        80.3      69.3             71.22       95.5       15.3      24.2
# 4151        80.3      69.3             71.22       95.5       15.3      24.2
#
#       ... Visibility Cloud Cover Sea Level Pressure  \
# 0     ...        9.4        66.8             1016.0
# 1     ...        9.4        75.6             1010.3
# 2     ...        9.9        64.2             1017.5
# 3     ...        8.8        76.1             1013.4
# 4     ...        8.2        66.1             1018.2
# ...   ...        ...         ...                ...
# 4147  ...        9.8        34.3             1018.7
# 4148  ...        9.9        59.3             1009.8
# 4149  ...        8.4        87.7             1009.7
# 4150  ...        9.9        43.1             1016.4
# 4151  ...        9.9        43.1             1016.4
#
#                                            Weather Type Latitude Longitude  \
# 0     Lightning Without Thunder|Mist|Thunderstorm|Ra...  33.5207  -86.8118
# 1                          Mist|Thunderstorm|Light Rain  41.5047  -81.6908
# 2                             Lightning Without Thunder  35.2229   -80.838
# 3     Lightning Without Thunder|Mist|Thunderstorm|Ra...  40.4385  -79.9973
# 4     Mist|Light Drizzle|Thunderstorm|Rain|Fog|Heavy...  35.9869  -78.6686
# ...                                                 ...      ...       ...
# 4147  Lightning Without Thunder|Mist|Rain|Thundersto...  32.0809  -81.0912
# 4148                                                     32.7782  -96.7951
# 4149  Lightning Without Thunder|Mist|Thunderstorm|Ra...  39.1034  -94.5831
# 4150  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
# 4151  Lightning Without Thunder|Light Drizzle|Thunde...  27.9465  -82.4593
#
#                               Resolved Address  \
# 0                  Birmingham|AL|United States
# 1                   Cleveland|OH|United States
# 2                   Charlotte|NC|United States
# 3                  Pittsburgh|PA|United States
# 4     Durham Rd|Raleigh|NC 27614|United States
# ...                                        ...
# 4147                 Savannah|GA|United States
# 4148                   Dallas|TX|United States
# 4149              Kansas City|MO|United States
# 4150                    Tampa|FL|United States
# 4151                    Tampa|FL|United States
#
#                                           Name Info             Conditions
# 0                  Birmingham|AL|United States       Rain|Partially cloudy
# 1                   Cleveland|OH|United States               Rain|Overcast
# 2                   Charlotte|NC|United States       Rain|Partially cloudy
# 3                  Pittsburgh|PA|United States               Rain|Overcast
# 4     Durham Rd|Raleigh|NC 27614|United States       Rain|Partially cloudy
# ...                                        ...  ...                    ...
# 4147                 Savannah|GA|United States       Rain|Partially cloudy
# 4148                   Dallas|TX|United States            Partially cloudy
# 4149              Kansas City|MO|United States               Rain|Overcast
# 4150                    Tampa|FL|United States       Rain|Partially cloudy
# 4151                    Tampa|FL|United States       Rain|Partially cloudy
#
# [4152 rows x 25 columns]

# %% [markdown]
# >All rows have same data from resolved area and Name. Dropping one of these columns since its a duplicate. Info has all NAN values. Dropping the 2 columns

# %%
weather_data_df = weather_data_df.drop(columns=['Info', 'Resolved Address'])

# %%
weather_data_df.shape
# Out:
# (4152, 23)

# %% [markdown]
# #### 6. Drop Duplicates

# %%
#Dropping dups from the copy and retaining the original df,
#to avoid having to recreate the df with multiple hits to the API. 
weather_data_df_copy = weather_data_df

# %%
weather_data_df_copy.shape, weather_data_df.shape
# Out:
# ((4152, 23), (4152, 23))

# %%
print('Dataframe before dropping duplicates :', weather_data_df_copy.shape)
weather_data_df_copy = weather_data_df_copy.drop_duplicates() # 1,389 rows dropped
print('Dataframe after dropping duplicates :',weather_data_df_copy.shape)
# Out:
# Dataframe before dropping duplicates : (4152, 23)
# Dataframe after dropping duplicates : (1376, 23)

# %% [markdown]
# #### 7. Replace column names

# %%
weather_data_df.columns
# Out:
# Index(['Address', 'Date time', 'Minimum Temperature', 'Maximum Temperature',
#        'Temperature', 'Dew Point', 'Relative Humidity', 'Heat Index',
#        'Wind Speed', 'Wind Gust', 'Wind Direction', 'Wind Chill',
#        'Precipitation', 'Precipitation Cover', 'Snow Depth', 'Visibility',
#        'Cloud Cover', 'Sea Level Pressure', 'Weather Type', 'Latitude',
#        'Longitude', 'Name', 'Conditions'],
#       dtype='object')

# %%
columns = ['ORIGIN', 'FL_DATE', 'MIN_TEMP', 'MAX_TEMP','TEMP', 'DEW_POINT', 'RELATIVE_HUMIDITY', 'HEAT_INDEX', 'WIND_SPEED',
           'WIND_GUST', 'WIND_DIRECTION', 'WIND_CHILL', 'PRECIPITATION', 'PRECIPITATION_COVER', 'SNOW_DEPTH', 
           'VISIBILITY','CLOUD_COVER', 'SEA_LEVEL_PRESSURE', 'WEATHER_TYPE', 'LATITUDE','LONGITUDE', 'CITY_NAME', 'CONDITIONS']

weather_data_df_copy.columns = columns

# %%
weather_data_df_copy.columns
# Out:
# Index(['ORIGIN', 'FL_DATE', 'MIN_TEMP', 'MAX_TEMP', 'TEMP', 'DEW_POINT',
#        'RELATIVE_HUMIDITY', 'HEAT_INDEX', 'WIND_SPEED', 'WIND_GUST',
#        'WIND_DIRECTION', 'WIND_CHILL', 'PRECIPITATION', 'PRECIPITATION_COVER',
#        'SNOW_DEPTH', 'VISIBILITY', 'CLOUD_COVER', 'SEA_LEVEL_PRESSURE',
#        'WEATHER_TYPE', 'LATITUDE', 'LONGITUDE', 'CITY_NAME', 'CONDITIONS'],
#       dtype='object')

# %% [markdown]
# #### 8. Fill NA/NaN values, if any

# %%
print(weather_data_df_copy[weather_data_df_copy.LATITUDE.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.LONGITUDE.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.MIN_TEMP.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.MAX_TEMP.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.TEMP.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.DEW_POINT.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.RELATIVE_HUMIDITY.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.HEAT_INDEX.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.WIND_SPEED.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.WIND_GUST.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.WIND_DIRECTION.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.WIND_CHILL.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.PRECIPITATION.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.PRECIPITATION_COVER.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.SNOW_DEPTH.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.VISIBILITY.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.CLOUD_COVER.isna()==True])
print(weather_data_df_copy[weather_data_df_copy.SEA_LEVEL_PRESSURE.isna()==True])
# Out:
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [ORIGIN, FL_DATE, MIN_TEMP, MAX_TEMP, TEMP, DEW_POINT, RELATIVE_HUMIDITY, HEAT_INDEX, WIND_SPEED, WIND_GUST, WIND_DIRECTION, WIND_CHILL, PRECIPITATION, PRECIPITATION_COVER, SNOW_DEPTH, VISIBILITY, CLOUD_COVER, SEA_LEVEL_PRESSURE, WEATHER_TYPE, LATITUDE, LONGITUDE, CITY_NAME, CONDITIONS]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# >There are no Nan values in numeric columns.

# %% [markdown]
# ### Ethical implications:
# >API Data -
# The data source of the API is genuine and reliable as stated in the terms of use in the website and I do not see any legal concers in using the data. However, I would like to validate the accuracy of the data by looking up the weather at a certain place and time known to have a bad weather situation.

# %% [markdown]
# ### Conclusion:
# >As a part of this milestone, the following Data Transformation steps have been performed.
#
# >1. Data manipulation using regular expressions to convert response text into a list of keys and values
# >2. Data transformation to parse the list of keys and values to form a dictionary (key-value pair)
# >3. Data transformation to convert the dictionary to a dataframe
# >4. Look for empty rows and null values
# >5. Drop Columns
# >6. Drop Duplicates
# >7. Replace column names
# >8. Fill NA/NaN values, if any
#
# >During the final project analysis, if there was no concerning weather condition at the origin airport, the same can be run against the destination airport to see if a flight was delayed/cancelled due to bad weather at the destination airport

# %% [markdown]
# ###### Following lines can be ignored. There is practice code that I would like to refer, if required.

# %% [raw]
# Bureau data is limited to carriers in USA. Get the unique operating carriers to identify US based carriers for flights diverted.

# %% [raw]
# json_data = response.text.splitlines()
# if len(json_data) <= 2:
#     keys = (re.split(',', json_data[0]))
#     # replace ', ' by | to be able to split the strings correctly for key value pair
#     values = (json_data[1].replace(', ','|').replace('"', '')).split(',')

# %% [raw]
#  match response.status_Code:
#             case 200:
#                 try:
#                     json_data = response.text.splitlines()
#                     if len(json_data) <= 2:
#                         keys = (re.split(',', json_data[0]))
#                         # replace ', ' by | to be able to split the strings correctly for key value pair
#                         values = (json_data[1].replace(', ','|').replace('"', '')).split(',')
#                         print(len(keys), len(values))
#                         if len(keys) == len(values):
#                             if index == 0:
#                                 for i in range(len(keys)):
#                                     historic_weather_data[keys[i]] = values[i]
#
#                             else:
#                                 for key, value in historic_weather_data.items():
#                                     historic_weather_data[key] = values[]
#                         else:
#                                 print("Key value pair counts don't match")
#
#                 except RuntimeError as ex:
#                     print('There was an error in processing the API response : ', ex)
#             case 404:
#                 print("Requested historic weather data not found for parms : Fl_Date - ",start_date_time, ' City - ',row.ORIGIN_CITY_NAME)
#             case _:
#                 print('Unable to get historic weather data for parms : Fl_Date - ',start_date_time, ' City - ',row.ORIGIN_CITY_NAME)

# %% [raw]
# historic_weather_data = {}
# print(len(keys), len(values))
# if len(keys) == len(values):
#     for i in range(len(keys)):
#         historic_weather_data[keys[i]] = values[i]
# else:
#     print("Key value pair counts don't match")
